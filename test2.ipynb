# %%
from tabnanny import verbose
import networkx as nx
import csv
import argparse

class Graph:
    def __init__(self):
        # Initialize an empty NetworkX graph
        self.G = nx.Graph()
        self.stream_paths = {}  # Dictionary to store paths for each stream
        # Dictionary to store queue assignments for each output port
        self.queue_assignments = {}
        self.streams = []

        # Default units for period, size, deadline and link rate
        self.period_unit = 1e-6  # 1 us 
        self.size_unit = 8  # 1 byte
        self.deadline_unit = 1e-6  # 1 us
        self.r_link = 1e9  # 1 Gbps link rate

    def load_from_csv(self, topology_file):
        """
        Loads a topology from a CSV file and populates the graph with nodes and edges.

        Args:
            topology_file (str): Path to the topology CSV file.
        """
        devices = []
        links = []

        # Use the csv module to read the file
        with open(topology_file, 'r') as file:
            reader = csv.reader(file)
            for fields in reader:
                if fields[0].lower() == 'es' or fields[0].lower() == 'sw':  # Device entry (SW or ES)
                    devices.append(fields)
                elif fields[0].lower() == 'link':  # Link entry
                    links.append(fields)

        # Add nodes (SW: Switch, ES: End System)
        for device in devices:
            device_type = device[0].strip()
            device_name = device[1].strip()
            self.G.add_node(device_name, type=device_type)

        # Add edges (LINK)
        for link in links:
            link_id = link[1].strip()
            source_device = link[2].strip()
            source_port = int(link[3].strip())
            destination_device = link[4].strip()
            destination_port = int(link[5].strip())

            # Add the edge (link) between source and destination devices, preserving direction information
            self.G.add_edge(
                source_device, destination_device, link_id=link_id,
                source_port=source_port, destination_port=destination_port,
                source_device=source_device, destination_device=destination_device
            )

    def load_streams(self, streams_file):
        """
        Loads stream information from a CSV file and units from the config.ini file.

        Args:
            streams_file (str): Path to the streams CSV file.
        """

        # read config file to get the units
        config_file = 'config.ini' # default config file

        with open(config_file, 'r') as file:
            for line in file:
                if 'PeriodUnit' in line:
                    period_unit = line.split('=')[1].strip()
                    if period_unit == 'MICROSECOND':
                        self.period_unit = 1e-6
                    elif period_unit == 'MILLISECOND':
                        self.period_unit = 1e-3
                    elif period_unit == 'SECOND':
                        self.period_unit = 1
                elif 'DeadlineUnit' in line:
                    deadline_unit = line.split('=')[1].strip()
                    if deadline_unit == 'MICROSECOND':
                        self.deadline_unit = 1e-6
                    elif deadline_unit == 'MILLISECOND':
                        self.deadline_unit = 1e-3
                    elif deadline_unit == 'SECOND':
                        self.deadline_unit = 1
                elif 'SizeUnit' in line:
                    size_unit = line.split('=')[1].strip()
                    if size_unit == 'BYTE':
                        self.size_unit = 8
                    elif size_unit == 'BIT':
                        self.size_unit = 1

        # Convert units of link rate to be consistent with period, size and deadline
        self.r_link = self.period_unit*self.r_link / self.size_unit

        streams = []
        with open(streams_file, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                streams.append({
                    'pcp': int(row[0]),
                    'name': row[1].strip(),
                    'type': row[2].strip(),
                    'source': row[3].strip(),
                    'destination': row[4].strip(),
                    'size': int(row[5]),
                    'period': float(row[6]),
                    'deadline': float(row[7])
                })
        self.streams = streams

    def find_shortest_path(self, node_a, node_b):
        """
        Finds the shortest path between two nodes using Dijkstra's algorithm.

        Args:
            node_a (str): The source node.
            node_b (str): The destination node.

        Returns:
            path (list): The shortest path from node_a to node_b as a list of nodes.
        """
        try:
            # Verify that nodes exist in the graph
            if node_a not in self.G or node_b not in self.G:
                print(
                    f"One or both of the nodes ({node_a}, {node_b}) are not in the graph.")
                return None

            # Use Dijkstra's algorithm to find the shortest path without weights
            path = nx.shortest_path(self.G, source=node_a, target=node_b)
            return path
        except nx.NetworkXNoPath:
            print(f"No path exists between {node_a} and {node_b}.")
            return None
        except nx.NodeNotFound:
            print(
                f"One or both of the nodes ({node_a}, {node_b}) are not in the graph.")
            return None

    def calculate_all_paths(self):
        """
        Calculates and stores the shortest paths for all streams, adjusting for the direction of traversal.
        """
        for stream in self.streams:
            source = stream['source']
            destination = stream['destination']
            path = self.find_shortest_path(source, destination)
            if path:
                annotated_path = []
                for i in range(len(path) - 1):
                    current_node = path[i]
                    next_node = path[i + 1]
                    
                    # Get edge data between current node and next node
                    edge_data = self.G.get_edge_data(current_node, next_node)
                    link_id = edge_data['link_id']
                    
                    # Determine direction of traversal and select appropriate ports
                    if current_node == edge_data['source_device']:
                        source_port = edge_data['source_port']
                        destination_port = edge_data['destination_port']
                    else:
                        # If reversed, swap ports
                        source_port = edge_data['destination_port']
                        destination_port = edge_data['source_port']

                    # Annotate the current node details for the path
                    annotated_path.append(f"{current_node}:{link_id}:{source_port}")
                
                # Append final destination node without outgoing link data
                annotated_path.append(f"{destination}")
                
                # Store annotated path in `stream_paths` dictionary
                self.stream_paths[stream['name']] = '->'.join(annotated_path)
                
                # Debug output
                # print(f"{stream['name']} from {source} to {destination}: {self.stream_        r_link = 1000000000  # Assume 1 Gbps link rate for nowpaths[stream['name']]}")
            else:
                print(f"No path found for Stream {stream['name']} from {source} to {destination}")



    def assign_queues(self):
        """
        Assigns shaped queues for each combination of priority level and upstream source for every output port.
        """
        for stream_name, path in self.stream_paths.items():
            stream = next(s for s in self.streams if s['name'] == stream_name)
            pcp = stream['pcp']
            path_nodes = path.split('->')
            for i in range(len(path_nodes) - 1):
                current_node = path_nodes[i].split(':')[0]
                previous_node = path_nodes[i - 1].split(':')[0] if i > 0 else 'N/A'
                next_node = path_nodes[i + 1].split(':')[0]
                
                # Get edge data between current and next node
                edge_data = self.G.get_edge_data(current_node, next_node)
                
                # Determine output port based on traversal direction
                if current_node == edge_data['source_device']:
                    output_port = edge_data['source_port']
                else:
                    output_port = edge_data['destination_port']

                # Create a queue assignment key for each (current_node, previous_node, output_port, pcp)
                key = (current_node, previous_node, output_port, pcp)

                if key not in self.queue_assignments:
                    self.queue_assignments[key] = []
                self.queue_assignments[key].append(stream_name)


    def compute_worst_case_delay(self, stream_name, verbose=False):
        """
        Computes the worst-case per-hop delay for a stream over its path.

        Args:
            stream_name (str): The name of the stream.

        Returns:
            float: The computed worst-case delay for the stream.
        """
        if stream_name not in self.stream_paths:
            print(f"No path found for stream {stream_name}.")
            return None

        header_size = 0  # Ethernet frame header size
        path = self.stream_paths[stream_name].split('->')
        stream = next(s for s in self.streams if s['name'] == stream_name)
        b = stream['size'] + header_size  # Include Ethernet frame overhead
        total_delay = 0

        if verbose:
            print(f"\nCalculating delay for stream: {stream_name}, size: {b}, period: {stream['period']}, deadline: {stream['deadline']}, pcp: {stream['pcp']}")

        for i in range(len(path) - 1):
            current_node = path[i].split(':')[0]
            next_node = path[i + 1].split(':')[0]
            edge_data = self.G.get_edge_data(current_node, next_node)

            # Determine output port based on traversal direction
            if current_node == edge_data['source_device']:
                output_port = edge_data['source_port']
            else:
                output_port = edge_data['destination_port']

            # Gather all streams at this output port across priority levels (including current stream)
            all_interfering_streams = [s_name for k, streams in self.queue_assignments.items() if k[0] == current_node and k[2] == output_port for s_name in streams]

            # Organize interfering streams by priority level relative to `stream['pcp']`
            higher_priority_streams = []
            same_priority_streams = []
            lower_priority_streams = []

            for s_name in all_interfering_streams:
                s_data = next((s for s in self.streams if s['name'] == s_name), None)
                if s_data:
                    if s_data['pcp'] > stream['pcp']:
                        higher_priority_streams.append(s_name)
                    elif s_data['pcp'] == stream['pcp']:
                        same_priority_streams.append(s_name)
                    else:
                        lower_priority_streams.append(s_name)

            # Debug output for all interfering streams organized by priority
            if verbose:
                print(f"  At hop {current_node} -> {next_node}, output port {output_port}, link_id {edge_data['link_id']}:")
                print("    Higher-priority streams:", higher_priority_streams)
                print("    Same-priority streams:", same_priority_streams)
                print("    Lower-priority streams:", lower_priority_streams)

            # Calculate r_H: Total rate of higher-priority streams
            r_H = sum(
                (s_data['size'] + header_size) / s_data['period']
                for s_name in higher_priority_streams
                for s_data in self.streams if s_data['name'] == s_name)

            # Calculate b_H: Total burst size of all higher-priority streams
            b_H = sum(
                (s_data['size'] + header_size) for s_name in higher_priority_streams
                for s_data in self.streams if s_data['name'] == s_name)

            # Calculate l_L: Maximum size of lower-priority streams
            l_L = max(
                [(s_data['size'] + header_size) for s_name in lower_priority_streams
                for s_data in self.streams if s_data['name'] == s_name] or [0])

            # Degug output for r_H, b_H, l_L
            if verbose:
                print(f"    For {stream_name}: b_total_H = {b_H}, l_max_L = {l_L}, r = {self.r_link}, r_total_H = {r_H}")
                print("\n    Iterating through same-priority streams:")

            # Do eq 10 in the project description
            temp_list = [] # List to store the results of the equation for each same-priority stream
            
            for j in same_priority_streams:
                # Sum burst of all same priority streams excluding stream j
                b_C_j = sum([(s_data['size'] + header_size) for s_name in same_priority_streams if s_name != j for s_data in self.streams if s_data['name'] == s_name])
                
                # Get burst for stream j
                b_j = next((s_data['size'] + header_size for s_data in self.streams if s_data['name'] == j), 0)

                # Get min minimum frame length of stream j (this is just the size of the stream for now...)
                l_j_min = b_j

                try:
                    # Construct the equation and append to the list
                    temp_result = (b_H + b_C_j + (b_j - l_j_min) + l_L) / (self.r_link - r_H) + (l_j_min / self.r_link)
                    temp_list.append(temp_result)
                except: 
                    return None
                
                if verbose:
                    print(f"        For j = {j}: b_C_j = {b_C_j}, b_j = {b_j}, l_j_min = {l_j_min}, temp_result = {temp_result}")
            
            # Calculate d_f as the max of the temp_list
            d_f = max(temp_list)

            if verbose:
                print(f"    d_f = {d_f}\n")

            total_delay += temp_result

        if verbose:
            print(f"d_f_total for {stream_name}: {total_delay}")

        return total_delay


    def compute_worst_case_delay_for_all_streams(self,topology_file, streams_file, output_file='output.csv', verbose=False):
        """
        Computes the worst-case per-hop delay for all streams over their respective paths.
        """

        if verbose:            
            print(f"Period unit: {self.period_unit}, Size unit: {self.size_unit}, Deadline unit: {self.deadline_unit}")

        # Build the graph
        self.load_from_csv(topology_file)

        # Load streams
        self.load_streams(streams_file)

        # calculate stream paths
        self.calculate_all_paths()

        # assign queues
        self.assign_queues()

        with open(output_file, 'w') as file:
            writer = csv.writer(file)
            writer.writerow('StreamName, MaxE2E(us), Deadline(us), Path'.split(','))
            for stream_name in self.stream_paths.keys():
                wcd = self.compute_worst_case_delay(stream_name,verbose=verbose)
                writer.writerow(f'{stream_name}, {round(wcd,3)}, {round(next(s_data["deadline"] for s_data in self.streams if s_data["name"] == stream_name),3)}, {self.stream_paths[stream_name]}'.split(','))


# Example usage
topology_file = 'topology_willy.csv'  # Replace with your actual file path
streams_file = 'streams_willy.csv'  # Replace with your actual file path

graph = Graph()
graph.compute_worst_case_delay_for_all_streams(topology_file = topology_file, streams_file = streams_file, output_file='output.csv', verbose=True)

# if __name__ == '__main__':
#     # use arogparse to get the file paths
#     parser = argparse.ArgumentParser(description='Compute worst-case delay for all streams')
#     parser.add_argument('--topology_file', '-tf',default='topology.scv', type=str, help='Path to the topology CSV file')
#     parser.add_argument('--streams_file', '-sf', default='streams.csv',type=str, help='Path to the streams CSV file')
#     args = parser.parse_args()

#     # Example usage
#     topology_file = 'topology.csv'  # Replace with your actual file path
#     streams_file = 'streams.csv'  # Replace with your actual file path

#     graph = Graph()
#     graph.compute_worst_case_delay_for_all_streams(topology_file = args.topology_file, streams_file = args.streams_file, output_file='output.csv', verbose=True)
# Out:
# Period unit: 1e-06, Size unit: 8, Deadline unit: 1e-06
#
# Calculating delay for stream: Stream_1, size: 602, period: 1000.0, deadline: 5544.0, pcp: 0
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Same-priority streams: ['Stream_1']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 2251, l_max_L = 0, r = 125.0, r_total_H = 2.6014999999999997
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 0, b_j = 602, l_j_min = 602, temp_result = 23.206748252633815
#     d_f = 23.206748252633815
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_6', 'Stream_8', 'Stream_26', 'Stream_30']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 5221, l_max_L = 0, r = 125.0, r_total_H = 7.0585
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 991, b_j = 602, l_j_min = 602, temp_result = 57.48617970773646
#         For j = Stream_5: b_C_j = 602, b_j = 991, l_j_min = 991, temp_result = 57.29993439120241
#     d_f = 57.48617970773646
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_16', 'Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 2469, l_max_L = 0, r = 125.0, r_total_H = 3.519
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 991, b_j = 602, l_j_min = 602, temp_result = 33.29782020233617
#         For j = Stream_5: b_C_j = 602, b_j = 991, l_j_min = 991, temp_result = 33.207673364559064
#     d_f = 33.29782020233617
#
# d_f_total for Stream_1: 113.7143560083953
#
# Calculating delay for stream: Stream_2, size: 717, period: 2000.0, deadline: 9538.0, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_2: b_total_H = 0, l_max_L = 602, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 1534, b_j = 717, l_j_min = 717, temp_result = 22.824
#         For j = Stream_3: b_C_j = 1701, b_j = 550, l_j_min = 550, temp_result = 22.823999999999998
#         For j = Stream_4: b_C_j = 1267, b_j = 984, l_j_min = 984, temp_result = 22.823999999999998
#     d_f = 22.824
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_2: b_total_H = 1487, l_max_L = 991, r = 125.0, r_total_H = 2.974
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 2383, b_j = 717, l_j_min = 717, temp_result = 45.571772704177796
#         For j = Stream_3: b_C_j = 2550, b_j = 550, l_j_min = 550, temp_result = 45.60433350269615
#         For j = Stream_4: b_C_j = 2116, b_j = 984, l_j_min = 984, temp_result = 45.519714421516724
#         For j = Stream_8: b_C_j = 2251, b_j = 849, l_j_min = 849, temp_result = 45.54603602510941
#     d_f = 45.60433350269615
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_2: b_total_H = 1631, l_max_L = 993, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 3285, b_j = 717, l_j_min = 717, temp_result = 54.00031430205014
#         For j = Stream_3: b_C_j = 3452, b_j = 550, l_j_min = 550, temp_result = 54.02835906232132
#         For j = Stream_4: b_C_j = 3018, b_j = 984, l_j_min = 984, temp_result = 53.955476272155515
#         For j = Stream_8: b_C_j = 3153, b_j = 849, l_j_min = 849, temp_result = 53.97814718614718
#         For j = Stream_9: b_C_j = 3100, b_j = 902, l_j_min = 902, temp_result = 53.96924675324675
#     d_f = 54.02835906232132
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2']
#     Lower-priority streams: ['Stream_33', 'Stream_34']
#     For Stream_2: b_total_H = 1631, l_max_L = 879, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 0, b_j = 717, l_j_min = 717, temp_result = 26.2375110675488
#     d_f = 26.2375110675488
#
# d_f_total for Stream_2: 148.57679384590497
#
# Calculating delay for stream: Stream_3, size: 550, period: 2000.0, deadline: 2634.0, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_3: b_total_H = 0, l_max_L = 602, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 1534, b_j = 717, l_j_min = 717, temp_result = 22.824
#         For j = Stream_3: b_C_j = 1701, b_j = 550, l_j_min = 550, temp_result = 22.823999999999998
#         For j = Stream_4: b_C_j = 1267, b_j = 984, l_j_min = 984, temp_result = 22.823999999999998
#     d_f = 22.824
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_3: b_total_H = 1487, l_max_L = 991, r = 125.0, r_total_H = 2.974
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 2383, b_j = 717, l_j_min = 717, temp_result = 45.571772704177796
#         For j = Stream_3: b_C_j = 2550, b_j = 550, l_j_min = 550, temp_result = 45.60433350269615
#         For j = Stream_4: b_C_j = 2116, b_j = 984, l_j_min = 984, temp_result = 45.519714421516724
#         For j = Stream_8: b_C_j = 2251, b_j = 849, l_j_min = 849, temp_result = 45.54603602510941
#     d_f = 45.60433350269615
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_3: b_total_H = 1631, l_max_L = 993, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 3285, b_j = 717, l_j_min = 717, temp_result = 54.00031430205014
#         For j = Stream_3: b_C_j = 3452, b_j = 550, l_j_min = 550, temp_result = 54.02835906232132
#         For j = Stream_4: b_C_j = 3018, b_j = 984, l_j_min = 984, temp_result = 53.955476272155515
#         For j = Stream_8: b_C_j = 3153, b_j = 849, l_j_min = 849, temp_result = 53.97814718614718
#         For j = Stream_9: b_C_j = 3100, b_j = 902, l_j_min = 902, temp_result = 53.96924675324675
#     d_f = 54.02835906232132
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_3: b_total_H = 949, l_max_L = 993, r = 125.0, r_total_H = 0.4745
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 2735, b_j = 550, l_j_min = 550, temp_result = 41.95857234060494
#         For j = Stream_4: b_C_j = 2301, b_j = 984, l_j_min = 984, temp_result = 41.94534240777993
#         For j = Stream_8: b_C_j = 2436, b_j = 849, l_j_min = 849, temp_result = 41.949457709465136
#         For j = Stream_9: b_C_j = 2383, b_j = 902, l_j_min = 902, temp_result = 41.94784207250724
#     d_f = 41.95857234060494
#
# d_f_total for Stream_3: 164.2871248508634
#
# Calculating delay for stream: Stream_4, size: 984, period: 500.0, deadline: 16976.0, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_4: b_total_H = 0, l_max_L = 602, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 1534, b_j = 717, l_j_min = 717, temp_result = 22.824
#         For j = Stream_3: b_C_j = 1701, b_j = 550, l_j_min = 550, temp_result = 22.823999999999998
#         For j = Stream_4: b_C_j = 1267, b_j = 984, l_j_min = 984, temp_result = 22.823999999999998
#     d_f = 22.824
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_4: b_total_H = 1487, l_max_L = 991, r = 125.0, r_total_H = 2.974
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 2383, b_j = 717, l_j_min = 717, temp_result = 45.571772704177796
#         For j = Stream_3: b_C_j = 2550, b_j = 550, l_j_min = 550, temp_result = 45.60433350269615
#         For j = Stream_4: b_C_j = 2116, b_j = 984, l_j_min = 984, temp_result = 45.519714421516724
#         For j = Stream_8: b_C_j = 2251, b_j = 849, l_j_min = 849, temp_result = 45.54603602510941
#     d_f = 45.60433350269615
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_4: b_total_H = 1631, l_max_L = 993, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 3285, b_j = 717, l_j_min = 717, temp_result = 54.00031430205014
#         For j = Stream_3: b_C_j = 3452, b_j = 550, l_j_min = 550, temp_result = 54.02835906232132
#         For j = Stream_4: b_C_j = 3018, b_j = 984, l_j_min = 984, temp_result = 53.955476272155515
#         For j = Stream_8: b_C_j = 3153, b_j = 849, l_j_min = 849, temp_result = 53.97814718614718
#         For j = Stream_9: b_C_j = 3100, b_j = 902, l_j_min = 902, temp_result = 53.96924675324675
#     d_f = 54.02835906232132
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_4: b_total_H = 949, l_max_L = 993, r = 125.0, r_total_H = 0.4745
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 2735, b_j = 550, l_j_min = 550, temp_result = 41.95857234060494
#         For j = Stream_4: b_C_j = 2301, b_j = 984, l_j_min = 984, temp_result = 41.94534240777993
#         For j = Stream_8: b_C_j = 2436, b_j = 849, l_j_min = 849, temp_result = 41.949457709465136
#         For j = Stream_9: b_C_j = 2383, b_j = 902, l_j_min = 902, temp_result = 41.94784207250724
#     d_f = 41.95857234060494
#
# d_f_total for Stream_4: 164.2871248508634
#
# Calculating delay for stream: Stream_5, size: 991, period: 1000.0, deadline: 18281.0, pcp: 0
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6', 'Stream_7', 'Stream_8']
#     Same-priority streams: ['Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 2698, l_max_L = 0, r = 125.0, r_total_H = 4.547
#
#     Iterating through same-priority streams:
#         For j = Stream_5: b_C_j = 0, b_j = 991, l_j_min = 991, temp_result = 30.326777946584976
#     d_f = 30.326777946584976
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_6', 'Stream_8', 'Stream_26', 'Stream_30']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 5221, l_max_L = 0, r = 125.0, r_total_H = 7.0585
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 991, b_j = 602, l_j_min = 602, temp_result = 57.48617970773646
#         For j = Stream_5: b_C_j = 602, b_j = 991, l_j_min = 991, temp_result = 57.29993439120241
#     d_f = 57.48617970773646
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_16', 'Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 2469, l_max_L = 0, r = 125.0, r_total_H = 3.519
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 991, b_j = 602, l_j_min = 602, temp_result = 33.29782020233617
#         For j = Stream_5: b_C_j = 602, b_j = 991, l_j_min = 991, temp_result = 33.207673364559064
#     d_f = 33.29782020233617
#
# d_f_total for Stream_5: 120.83438570234645
#
# Calculating delay for stream: Stream_6, size: 939, period: 500.0, deadline: 19211.0, pcp: 6
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_5', 'Stream_7', 'Stream_8']
#     For Stream_6: b_total_H = 0, l_max_L = 991, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 939, l_j_min = 939, temp_result = 15.44
#     d_f = 15.44
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6', 'Stream_26']
#     Lower-priority streams: ['Stream_1', 'Stream_2', 'Stream_3', 'Stream_4', 'Stream_5', 'Stream_8', 'Stream_30']
#     For Stream_6: b_total_H = 0, l_max_L = 991, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 548, b_j = 939, l_j_min = 939, temp_result = 19.823999999999998
#         For j = Stream_26: b_C_j = 939, b_j = 548, l_j_min = 548, temp_result = 19.823999999999998
#     d_f = 19.823999999999998
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_34', 'Stream_40', 'Stream_36']
#     For Stream_6: b_total_H = 0, l_max_L = 993, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 939, l_j_min = 939, temp_result = 15.456
#     d_f = 15.456
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_2', 'Stream_33', 'Stream_34', 'Stream_36']
#     For Stream_6: b_total_H = 0, l_max_L = 879, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 939, l_j_min = 939, temp_result = 14.544
#     d_f = 14.544
#
# d_f_total for Stream_6: 65.264
#
# Calculating delay for stream: Stream_7, size: 910, period: 500.0, deadline: 3915.0, pcp: 2
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6', 'Stream_8']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: ['Stream_5']
#     For Stream_7: b_total_H = 1788, l_max_L = 991, r = 125.0, r_total_H = 2.727
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 910, l_j_min = 910, temp_result = 30.007830346846813
#     d_f = 30.007830346846813
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_11', 'Stream_15', 'Stream_19', 'Stream_20', 'Stream_24']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: []
#     For Stream_7: b_total_H = 3798, l_max_L = 0, r = 125.0, r_total_H = 5.3935
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 910, l_j_min = 910, temp_result = 39.034127075033545
#     d_f = 39.034127075033545
#
#   At hop Switch_4 -> ES_8, output port 2, link_id Link_8:
#     Higher-priority streams: ['Stream_19', 'Stream_24']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: []
#     For Stream_7: b_total_H = 1435, l_max_L = 0, r = 125.0, r_total_H = 2.87
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 910, l_j_min = 910, temp_result = 19.029774830099075
#     d_f = 19.029774830099075
#
# d_f_total for Stream_7: 88.07173225197943
#
# Calculating delay for stream: Stream_8, size: 849, period: 1000.0, deadline: 16436.0, pcp: 3
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_8']
#     Lower-priority streams: ['Stream_5', 'Stream_7']
#     For Stream_8: b_total_H = 939, l_max_L = 991, r = 125.0, r_total_H = 1.878
#
#     Iterating through same-priority streams:
#         For j = Stream_8: b_C_j = 0, b_j = 849, l_j_min = 849, temp_result = 22.46750884488556
#     d_f = 22.46750884488556
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_8: b_total_H = 1487, l_max_L = 991, r = 125.0, r_total_H = 2.974
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 2383, b_j = 717, l_j_min = 717, temp_result = 45.571772704177796
#         For j = Stream_3: b_C_j = 2550, b_j = 550, l_j_min = 550, temp_result = 45.60433350269615
#         For j = Stream_4: b_C_j = 2116, b_j = 984, l_j_min = 984, temp_result = 45.519714421516724
#         For j = Stream_8: b_C_j = 2251, b_j = 849, l_j_min = 849, temp_result = 45.54603602510941
#     d_f = 45.60433350269615
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_8: b_total_H = 1631, l_max_L = 993, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 3285, b_j = 717, l_j_min = 717, temp_result = 54.00031430205014
#         For j = Stream_3: b_C_j = 3452, b_j = 550, l_j_min = 550, temp_result = 54.02835906232132
#         For j = Stream_4: b_C_j = 3018, b_j = 984, l_j_min = 984, temp_result = 53.955476272155515
#         For j = Stream_8: b_C_j = 3153, b_j = 849, l_j_min = 849, temp_result = 53.97814718614718
#         For j = Stream_9: b_C_j = 3100, b_j = 902, l_j_min = 902, temp_result = 53.96924675324675
#     d_f = 54.02835906232132
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_8: b_total_H = 949, l_max_L = 993, r = 125.0, r_total_H = 0.4745
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 2735, b_j = 550, l_j_min = 550, temp_result = 41.95857234060494
#         For j = Stream_4: b_C_j = 2301, b_j = 984, l_j_min = 984, temp_result = 41.94534240777993
#         For j = Stream_8: b_C_j = 2436, b_j = 849, l_j_min = 849, temp_result = 41.949457709465136
#         For j = Stream_9: b_C_j = 2383, b_j = 902, l_j_min = 902, temp_result = 41.94784207250724
#     d_f = 41.95857234060494
#
# d_f_total for Stream_8: 163.93063369574895
#
# Calculating delay for stream: Stream_9, size: 902, period: 1000.0, deadline: 15562.0, pcp: 3
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_11', 'Stream_12']
#     Same-priority streams: ['Stream_9']
#     Lower-priority streams: ['Stream_10']
#     For Stream_9: b_total_H = 1289, l_max_L = 817, r = 125.0, r_total_H = 1.89
#
#     Iterating through same-priority streams:
#         For j = Stream_9: b_C_j = 0, b_j = 902, l_j_min = 902, temp_result = 24.322652587117215
#     d_f = 24.322652587117215
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_9: b_total_H = 1631, l_max_L = 993, r = 125.0, r_total_H = 2.57
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 3285, b_j = 717, l_j_min = 717, temp_result = 54.00031430205014
#         For j = Stream_3: b_C_j = 3452, b_j = 550, l_j_min = 550, temp_result = 54.02835906232132
#         For j = Stream_4: b_C_j = 3018, b_j = 984, l_j_min = 984, temp_result = 53.955476272155515
#         For j = Stream_8: b_C_j = 3153, b_j = 849, l_j_min = 849, temp_result = 53.97814718614718
#         For j = Stream_9: b_C_j = 3100, b_j = 902, l_j_min = 902, temp_result = 53.96924675324675
#     d_f = 54.02835906232132
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_9: b_total_H = 949, l_max_L = 993, r = 125.0, r_total_H = 0.4745
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 2735, b_j = 550, l_j_min = 550, temp_result = 41.95857234060494
#         For j = Stream_4: b_C_j = 2301, b_j = 984, l_j_min = 984, temp_result = 41.94534240777993
#         For j = Stream_8: b_C_j = 2436, b_j = 849, l_j_min = 849, temp_result = 41.949457709465136
#         For j = Stream_9: b_C_j = 2383, b_j = 902, l_j_min = 902, temp_result = 41.94784207250724
#     d_f = 41.95857234060494
#
# d_f_total for Stream_9: 120.23974141287121
#
# Calculating delay for stream: Stream_10, size: 817, period: 1000.0, deadline: 18069.0, pcp: 1
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_9', 'Stream_11', 'Stream_12']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 2191, l_max_L = 0, r = 125.0, r_total_H = 2.792
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 817, l_j_min = 817, temp_result = 24.46444985598324
#     d_f = 24.46444985598324
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: ['Stream_12', 'Stream_14']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 1376, l_max_L = 0, r = 125.0, r_total_H = 1.032
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 817, l_j_min = 817, temp_result = 17.63563861641714
#     d_f = 17.63563861641714
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_14', 'Stream_27', 'Stream_38']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 2352, l_max_L = 0, r = 125.0, r_total_H = 2.953
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 817, l_j_min = 817, temp_result = 25.80726434898031
#     d_f = 25.80726434898031
#
# d_f_total for Stream_10: 67.9073528213807
#
# Calculating delay for stream: Stream_11, size: 601, period: 500.0, deadline: 12906.0, pcp: 6
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_9', 'Stream_10', 'Stream_12']
#     For Stream_11: b_total_H = 0, l_max_L = 902, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 601, l_j_min = 601, temp_result = 12.024000000000001
#     d_f = 12.024000000000001
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_11: b_total_H = 1626, l_max_L = 881, r = 125.0, r_total_H = 2.371
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 601, l_j_min = 601, temp_result = 25.251777573004752
#     d_f = 25.251777573004752
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_7', 'Stream_15', 'Stream_24']
#     For Stream_11: b_total_H = 1626, l_max_L = 910, r = 125.0, r_total_H = 2.371
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 601, l_j_min = 601, temp_result = 25.48826323300361
#     d_f = 25.48826323300361
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_15', 'Stream_31', 'Stream_37']
#     For Stream_11: b_total_H = 881, l_max_L = 995, r = 125.0, r_total_H = 0.881
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 601, l_j_min = 601, temp_result = 19.922527187618336
#     d_f = 19.922527187618336
#
# d_f_total for Stream_11: 82.68656799362671
#
# Calculating delay for stream: Stream_12, size: 688, period: 1000.0, deadline: 1795.0, pcp: 4
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_11']
#     Same-priority streams: ['Stream_12']
#     Lower-priority streams: ['Stream_9', 'Stream_10']
#     For Stream_12: b_total_H = 601, l_max_L = 902, r = 125.0, r_total_H = 1.202
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 0, b_j = 688, l_j_min = 688, temp_result = 17.644745407841807
#     d_f = 17.644745407841807
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_14']
#     Lower-priority streams: ['Stream_10']
#     For Stream_12: b_total_H = 0, l_max_L = 817, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 688, b_j = 688, l_j_min = 688, temp_result = 17.543999999999997
#         For j = Stream_14: b_C_j = 688, b_j = 688, l_j_min = 688, temp_result = 17.543999999999997
#     d_f = 17.543999999999997
#
#   At hop Switch_5 -> ES_10, output port 2, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_32']
#     Lower-priority streams: ['Stream_25', 'Stream_28']
#     For Stream_12: b_total_H = 0, l_max_L = 887, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 511, b_j = 688, l_j_min = 688, temp_result = 16.688
#         For j = Stream_32: b_C_j = 688, b_j = 511, l_j_min = 511, temp_result = 16.688
#     d_f = 16.688
#
# d_f_total for Stream_12: 51.87674540784181
#
# Calculating delay for stream: Stream_13, size: 762, period: 500.0, deadline: 19237.0, pcp: 4
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_16']
#     Same-priority streams: ['Stream_13', 'Stream_14']
#     Lower-priority streams: ['Stream_15']
#     For Stream_13: b_total_H = 946, l_max_L = 881, r = 125.0, r_total_H = 0.473
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 688, b_j = 762, l_j_min = 762, temp_result = 26.292423265637172
#         For j = Stream_14: b_C_j = 762, b_j = 688, l_j_min = 688, temp_result = 26.29467190247898
#     d_f = 26.29467190247898
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_11', 'Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_13', 'Stream_23', 'Stream_24']
#     Lower-priority streams: ['Stream_15']
#     For Stream_13: b_total_H = 2227, l_max_L = 881, r = 125.0, r_total_H = 3.5730000000000004
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 1324, b_j = 762, l_j_min = 762, temp_result = 42.595295873240715
#         For j = Stream_23: b_C_j = 1452, b_j = 634, l_j_min = 634, temp_result = 42.62542716199857
#         For j = Stream_24: b_C_j = 1396, b_j = 690, l_j_min = 690, temp_result = 42.61224472316701
#     d_f = 42.62542716199857
#
#   At hop Switch_1 -> ES_2, output port 2, link_id Link_2:
#     Higher-priority streams: ['Stream_39']
#     Same-priority streams: ['Stream_13']
#     Lower-priority streams: ['Stream_29']
#     For Stream_13: b_total_H = 723, l_max_L = 744, r = 125.0, r_total_H = 0.3615
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 0, b_j = 762, l_j_min = 762, temp_result = 17.866038952651067
#     d_f = 17.866038952651067
#
# d_f_total for Stream_13: 86.77295557829706
#
# Calculating delay for stream: Stream_14, size: 688, period: 2000.0, deadline: 3946.0, pcp: 4
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_16']
#     Same-priority streams: ['Stream_13', 'Stream_14']
#     Lower-priority streams: ['Stream_15']
#     For Stream_14: b_total_H = 946, l_max_L = 881, r = 125.0, r_total_H = 0.473
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 688, b_j = 762, l_j_min = 762, temp_result = 26.292423265637172
#         For j = Stream_14: b_C_j = 762, b_j = 688, l_j_min = 688, temp_result = 26.29467190247898
#     d_f = 26.29467190247898
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_14']
#     Lower-priority streams: ['Stream_10']
#     For Stream_14: b_total_H = 0, l_max_L = 817, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 688, b_j = 688, l_j_min = 688, temp_result = 17.543999999999997
#         For j = Stream_14: b_C_j = 688, b_j = 688, l_j_min = 688, temp_result = 17.543999999999997
#     d_f = 17.543999999999997
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_27']
#     Same-priority streams: ['Stream_14', 'Stream_38']
#     Lower-priority streams: ['Stream_10']
#     For Stream_14: b_total_H = 719, l_max_L = 817, r = 125.0, r_total_H = 0.719
#
#     Iterating through same-priority streams:
#         For j = Stream_14: b_C_j = 945, b_j = 688, l_j_min = 688, temp_result = 25.4668261761653
#         For j = Stream_38: b_C_j = 688, b_j = 945, l_j_min = 945, temp_result = 25.45493164683258
#     d_f = 25.4668261761653
#
# d_f_total for Stream_14: 69.29360354931156
#
# Calculating delay for stream: Stream_15, size: 881, period: 2000.0, deadline: 8364.0, pcp: 3
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_13', 'Stream_14', 'Stream_16']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: []
#     For Stream_15: b_total_H = 2396, l_max_L = 0, r = 125.0, r_total_H = 2.3409999999999997
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 881, l_j_min = 881, temp_result = 26.581829559999676
#     d_f = 26.581829559999676
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_11', 'Stream_13', 'Stream_19', 'Stream_20', 'Stream_23', 'Stream_24']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: []
#     For Stream_15: b_total_H = 4313, l_max_L = 0, r = 125.0, r_total_H = 7.111000000000001
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 881, l_j_min = 881, temp_result = 43.63326240785824
#     d_f = 43.63326240785824
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_11', 'Stream_19', 'Stream_20', 'Stream_24']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: ['Stream_7']
#     For Stream_15: b_total_H = 2917, l_max_L = 910, r = 125.0, r_total_H = 4.953
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 881, l_j_min = 881, temp_result = 38.927180654243756
#     d_f = 38.927180654243756
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_11', 'Stream_20', 'Stream_37']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: ['Stream_31']
#     For Stream_15: b_total_H = 2477, l_max_L = 539, r = 125.0, r_total_H = 2.5805000000000002
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 881, l_j_min = 881, temp_result = 31.684597927617737
#     d_f = 31.684597927617737
#
# d_f_total for Stream_15: 140.82687054971942
#
# Calculating delay for stream: Stream_16, size: 946, period: 2000.0, deadline: 16124.0, pcp: 5
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_16']
#     Lower-priority streams: ['Stream_13', 'Stream_14', 'Stream_15']
#     For Stream_16: b_total_H = 0, l_max_L = 881, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_16: b_C_j = 0, b_j = 946, l_j_min = 946, temp_result = 14.616
#     d_f = 14.616
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_16']
#     Lower-priority streams: ['Stream_1', 'Stream_5']
#     For Stream_16: b_total_H = 1523, l_max_L = 991, r = 125.0, r_total_H = 3.0460000000000003
#
#     Iterating through same-priority streams:
#         For j = Stream_16: b_C_j = 0, b_j = 946, l_j_min = 946, temp_result = 28.182329993276156
#     d_f = 28.182329993276156
#
# d_f_total for Stream_16: 42.798329993276155
#
# Calculating delay for stream: Stream_17, size: 949, period: 2000.0, deadline: 8418.0, pcp: 4
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_17']
#     Lower-priority streams: []
#     For Stream_17: b_total_H = 2601, l_max_L = 0, r = 125.0, r_total_H = 4.321
#
#     Iterating through same-priority streams:
#         For j = Stream_17: b_C_j = 0, b_j = 949, l_j_min = 949, temp_result = 29.145045683176026
#     d_f = 29.145045683176026
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_17']
#     Lower-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_40']
#     For Stream_17: b_total_H = 0, l_max_L = 993, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_17: b_C_j = 0, b_j = 949, l_j_min = 949, temp_result = 15.536
#     d_f = 15.536
#
# d_f_total for Stream_17: 44.68104568317602
#
# Calculating delay for stream: Stream_18, size: 975, period: 500.0, deadline: 11136.0, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_18: b_total_H = 0, l_max_L = 949, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 1626, b_j = 975, l_j_min = 975, temp_result = 28.400000000000002
#         For j = Stream_19: b_C_j = 1856, b_j = 745, l_j_min = 745, temp_result = 28.400000000000002
#         For j = Stream_20: b_C_j = 1720, b_j = 881, l_j_min = 881, temp_result = 28.4
#     d_f = 28.400000000000002
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_18: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 3024, b_j = 975, l_j_min = 975, temp_result = 37.512
#         For j = Stream_19: b_C_j = 3254, b_j = 745, l_j_min = 745, temp_result = 37.512
#         For j = Stream_20: b_C_j = 3118, b_j = 881, l_j_min = 881, temp_result = 37.512
#         For j = Stream_21: b_C_j = 3473, b_j = 526, l_j_min = 526, temp_result = 37.512
#         For j = Stream_22: b_C_j = 3127, b_j = 872, l_j_min = 872, temp_result = 37.512
#     d_f = 37.512
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_16', 'Stream_26']
#     For Stream_18: b_total_H = 0, l_max_L = 991, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 0, b_j = 975, l_j_min = 975, temp_result = 15.728
#     d_f = 15.728
#
# d_f_total for Stream_18: 81.64
#
# Calculating delay for stream: Stream_19, size: 745, period: 500.0, deadline: 4352.0, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_19: b_total_H = 0, l_max_L = 949, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 1626, b_j = 975, l_j_min = 975, temp_result = 28.400000000000002
#         For j = Stream_19: b_C_j = 1856, b_j = 745, l_j_min = 745, temp_result = 28.400000000000002
#         For j = Stream_20: b_C_j = 1720, b_j = 881, l_j_min = 881, temp_result = 28.4
#     d_f = 28.400000000000002
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 3024, b_j = 975, l_j_min = 975, temp_result = 37.512
#         For j = Stream_19: b_C_j = 3254, b_j = 745, l_j_min = 745, temp_result = 37.512
#         For j = Stream_20: b_C_j = 3118, b_j = 881, l_j_min = 881, temp_result = 37.512
#         For j = Stream_21: b_C_j = 3473, b_j = 526, l_j_min = 526, temp_result = 37.512
#         For j = Stream_22: b_C_j = 3127, b_j = 872, l_j_min = 872, temp_result = 37.512
#     d_f = 37.512
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 881, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 881, b_j = 745, l_j_min = 745, temp_result = 20.056
#         For j = Stream_20: b_C_j = 745, b_j = 881, l_j_min = 881, temp_result = 20.055999999999997
#     d_f = 20.056
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_7', 'Stream_11', 'Stream_15', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 910, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 881, b_j = 745, l_j_min = 745, temp_result = 20.288
#         For j = Stream_20: b_C_j = 745, b_j = 881, l_j_min = 881, temp_result = 20.288
#     d_f = 20.288
#
#   At hop Switch_4 -> ES_8, output port 2, link_id Link_8:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19']
#     Lower-priority streams: ['Stream_7', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 910, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 0, b_j = 745, l_j_min = 745, temp_result = 13.24
#     d_f = 13.24
#
# d_f_total for Stream_19: 119.496
#
# Calculating delay for stream: Stream_20, size: 881, period: 1000.0, deadline: 9970.0, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_20: b_total_H = 0, l_max_L = 949, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 1626, b_j = 975, l_j_min = 975, temp_result = 28.400000000000002
#         For j = Stream_19: b_C_j = 1856, b_j = 745, l_j_min = 745, temp_result = 28.400000000000002
#         For j = Stream_20: b_C_j = 1720, b_j = 881, l_j_min = 881, temp_result = 28.4
#     d_f = 28.400000000000002
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 3024, b_j = 975, l_j_min = 975, temp_result = 37.512
#         For j = Stream_19: b_C_j = 3254, b_j = 745, l_j_min = 745, temp_result = 37.512
#         For j = Stream_20: b_C_j = 3118, b_j = 881, l_j_min = 881, temp_result = 37.512
#         For j = Stream_21: b_C_j = 3473, b_j = 526, l_j_min = 526, temp_result = 37.512
#         For j = Stream_22: b_C_j = 3127, b_j = 872, l_j_min = 872, temp_result = 37.512
#     d_f = 37.512
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 881, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 881, b_j = 745, l_j_min = 745, temp_result = 20.056
#         For j = Stream_20: b_C_j = 745, b_j = 881, l_j_min = 881, temp_result = 20.055999999999997
#     d_f = 20.056
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_7', 'Stream_11', 'Stream_15', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 910, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 881, b_j = 745, l_j_min = 745, temp_result = 20.288
#         For j = Stream_20: b_C_j = 745, b_j = 881, l_j_min = 881, temp_result = 20.288
#     d_f = 20.288
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_15', 'Stream_31', 'Stream_37']
#     For Stream_20: b_total_H = 0, l_max_L = 995, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_20: b_C_j = 0, b_j = 881, l_j_min = 881, temp_result = 15.008
#     d_f = 15.008
#
# d_f_total for Stream_20: 121.264
#
# Calculating delay for stream: Stream_21, size: 526, period: 500.0, deadline: 9733.0, pcp: 7
#   At hop ES_6 -> Switch_3, output port 1, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_21: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 872, b_j = 526, l_j_min = 526, temp_result = 16.704
#         For j = Stream_22: b_C_j = 526, b_j = 872, l_j_min = 872, temp_result = 16.704
#     d_f = 16.704
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_21: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 3024, b_j = 975, l_j_min = 975, temp_result = 37.512
#         For j = Stream_19: b_C_j = 3254, b_j = 745, l_j_min = 745, temp_result = 37.512
#         For j = Stream_20: b_C_j = 3118, b_j = 881, l_j_min = 881, temp_result = 37.512
#         For j = Stream_21: b_C_j = 3473, b_j = 526, l_j_min = 526, temp_result = 37.512
#         For j = Stream_22: b_C_j = 3127, b_j = 872, l_j_min = 872, temp_result = 37.512
#     d_f = 37.512
#
#   At hop Switch_2 -> ES_4, output port 2, link_id Link_4:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_35']
#     For Stream_21: b_total_H = 0, l_max_L = 548, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 872, b_j = 526, l_j_min = 526, temp_result = 15.568
#         For j = Stream_22: b_C_j = 526, b_j = 872, l_j_min = 872, temp_result = 15.568000000000001
#     d_f = 15.568000000000001
#
# d_f_total for Stream_21: 69.784
#
# Calculating delay for stream: Stream_22, size: 872, period: 1000.0, deadline: 7356.0, pcp: 7
#   At hop ES_6 -> Switch_3, output port 1, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_22: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 872, b_j = 526, l_j_min = 526, temp_result = 16.704
#         For j = Stream_22: b_C_j = 526, b_j = 872, l_j_min = 872, temp_result = 16.704
#     d_f = 16.704
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_22: b_total_H = 0, l_max_L = 690, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 3024, b_j = 975, l_j_min = 975, temp_result = 37.512
#         For j = Stream_19: b_C_j = 3254, b_j = 745, l_j_min = 745, temp_result = 37.512
#         For j = Stream_20: b_C_j = 3118, b_j = 881, l_j_min = 881, temp_result = 37.512
#         For j = Stream_21: b_C_j = 3473, b_j = 526, l_j_min = 526, temp_result = 37.512
#         For j = Stream_22: b_C_j = 3127, b_j = 872, l_j_min = 872, temp_result = 37.512
#     d_f = 37.512
#
#   At hop Switch_2 -> ES_4, output port 2, link_id Link_4:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_35']
#     For Stream_22: b_total_H = 0, l_max_L = 548, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 872, b_j = 526, l_j_min = 526, temp_result = 15.568
#         For j = Stream_22: b_C_j = 526, b_j = 872, l_j_min = 872, temp_result = 15.568000000000001
#     d_f = 15.568000000000001
#
# d_f_total for Stream_22: 69.784
#
# Calculating delay for stream: Stream_23, size: 634, period: 1000.0, deadline: 17711.0, pcp: 4
#   At hop ES_6 -> Switch_3, output port 1, link_id Link_6:
#     Higher-priority streams: ['Stream_21', 'Stream_22']
#     Same-priority streams: ['Stream_23', 'Stream_24']
#     Lower-priority streams: []
#     For Stream_23: b_total_H = 1398, l_max_L = 0, r = 125.0, r_total_H = 1.924
#
#     Iterating through same-priority streams:
#         For j = Stream_23: b_C_j = 690, b_j = 634, l_j_min = 634, temp_result = 22.03712723845429
#         For j = Stream_24: b_C_j = 634, b_j = 690, l_j_min = 690, temp_result = 22.030123825928694
#     d_f = 22.03712723845429
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Same-priority streams: ['Stream_23', 'Stream_24']
# ...
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_32']
#     Lower-priority streams: ['Stream_25', 'Stream_28']
#     For Stream_32: b_total_H = 0, l_max_L = 887, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 511, b_j = 688, l_j_min = 688, temp_result = 16.688
#         For j = Stream_32: b_C_j = 688, b_j = 511, l_j_min = 511, temp_result = 16.688
#     d_f = 16.688
#
# d_f_total for Stream_32: 43.73832923777569
#
# Calculating delay for stream: Stream_33, size: 879, period: 1000.0, deadline: 19859.0, pcp: 2
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34', 'Stream_35']
#     For Stream_33: b_total_H = 692, l_max_L = 703, r = 125.0, r_total_H = 0.692
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 879, l_j_min = 879, temp_result = 18.2541256878077
#     d_f = 18.2541256878077
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     For Stream_33: b_total_H = 692, l_max_L = 993, r = 125.0, r_total_H = 0.692
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 879, l_j_min = 879, temp_result = 20.58704070534479
#     d_f = 20.58704070534479
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_30', 'Stream_34', 'Stream_40']
#     For Stream_33: b_total_H = 5633, l_max_L = 993, r = 125.0, r_total_H = 6.9225
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 879, l_j_min = 879, temp_result = 63.14768673117233
#     d_f = 63.14768673117233
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_2', 'Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34']
#     For Stream_33: b_total_H = 2348, l_max_L = 703, r = 125.0, r_total_H = 2.9284999999999997
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 879, l_j_min = 879, temp_result = 32.025548862756665
#     d_f = 32.025548862756665
#
# d_f_total for Stream_33: 134.0144019870815
#
# Calculating delay for stream: Stream_34, size: 703, period: 500.0, deadline: 5841.0, pcp: 0
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 1571, l_max_L = 0, r = 125.0, r_total_H = 1.571
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 548, b_j = 703, l_j_min = 703, temp_result = 22.791764463780794
#         For j = Stream_35: b_C_j = 703, b_j = 548, l_j_min = 548, temp_result = 22.807547140461317
#     d_f = 22.807547140461317
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 1571, l_max_L = 0, r = 125.0, r_total_H = 1.571
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 1541, b_j = 703, l_j_min = 703, temp_result = 30.836875418256646
#         For j = Stream_35: b_C_j = 1696, b_j = 548, l_j_min = 548, temp_result = 30.85265809493717
#         For j = Stream_40: b_C_j = 1251, b_j = 993, l_j_min = 993, temp_result = 30.807346539305996
#     d_f = 30.85265809493717
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 7146, l_max_L = 0, r = 125.0, r_total_H = 8.435500000000001
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 993, b_j = 703, l_j_min = 703, temp_result = 75.44800301978732
#         For j = Stream_40: b_C_j = 703, b_j = 993, l_j_min = 993, temp_result = 75.28011005065865
#     d_f = 75.44800301978732
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_2', 'Stream_6', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 3227, l_max_L = 0, r = 125.0, r_total_H = 3.8075
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 0, b_j = 703, l_j_min = 703, temp_result = 32.25106025537884
#     d_f = 32.25106025537884
#
# d_f_total for Stream_34: 161.1460639858048
#
# Calculating delay for stream: Stream_35, size: 548, period: 2000.0, deadline: 9433.0, pcp: 0
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 1571, l_max_L = 0, r = 125.0, r_total_H = 1.571
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 548, b_j = 703, l_j_min = 703, temp_result = 22.791764463780794
#         For j = Stream_35: b_C_j = 703, b_j = 548, l_j_min = 548, temp_result = 22.807547140461317
#     d_f = 22.807547140461317
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 1571, l_max_L = 0, r = 125.0, r_total_H = 1.571
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 1541, b_j = 703, l_j_min = 703, temp_result = 30.836875418256646
#         For j = Stream_35: b_C_j = 1696, b_j = 548, l_j_min = 548, temp_result = 30.85265809493717
#         For j = Stream_40: b_C_j = 1251, b_j = 993, l_j_min = 993, temp_result = 30.807346539305996
#     d_f = 30.85265809493717
#
#   At hop Switch_2 -> ES_4, output port 2, link_id Link_4:
#     Higher-priority streams: ['Stream_21', 'Stream_22']
#     Same-priority streams: ['Stream_35']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 1398, l_max_L = 0, r = 125.0, r_total_H = 1.924
#
#     Iterating through same-priority streams:
#         For j = Stream_35: b_C_j = 0, b_j = 548, l_j_min = 548, temp_result = 15.742835191263936
#     d_f = 15.742835191263936
#
# d_f_total for Stream_35: 69.35772887103124
#
# Calculating delay for stream: Stream_36, size: 692, period: 1000.0, deadline: 1219.0, pcp: 4
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_33', 'Stream_34', 'Stream_35']
#     For Stream_36: b_total_H = 0, l_max_L = 879, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 692, l_j_min = 692, temp_result = 12.568
#     d_f = 12.568
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_33', 'Stream_34', 'Stream_35', 'Stream_40']
#     For Stream_36: b_total_H = 0, l_max_L = 993, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 692, l_j_min = 692, temp_result = 13.48
#     d_f = 13.48
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_36: b_total_H = 939, l_max_L = 993, r = 125.0, r_total_H = 1.878
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 692, l_j_min = 692, temp_result = 21.22775289550202
#     d_f = 21.22775289550202
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_2', 'Stream_33', 'Stream_34']
#     For Stream_36: b_total_H = 939, l_max_L = 879, r = 125.0, r_total_H = 1.878
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 692, l_j_min = 692, temp_result = 20.301842010363703
#     d_f = 20.301842010363703
#
# d_f_total for Stream_36: 67.57759490586572
#
# Calculating delay for stream: Stream_37, size: 995, period: 2000.0, deadline: 10151.0, pcp: 5
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: ['Stream_38', 'Stream_40']
#     For Stream_37: b_total_H = 0, l_max_L = 993, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 723, b_j = 995, l_j_min = 995, temp_result = 21.688
#         For j = Stream_39: b_C_j = 995, b_j = 723, l_j_min = 723, temp_result = 21.688
#     d_f = 21.688
#
#   At hop Switch_5 -> Switch_4, output port 4, link_id Link_15:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: []
#     For Stream_37: b_total_H = 0, l_max_L = 0, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 723, b_j = 995, l_j_min = 995, temp_result = 13.744
#         For j = Stream_39: b_C_j = 995, b_j = 723, l_j_min = 723, temp_result = 13.744
#     d_f = 13.744
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_11', 'Stream_20']
#     Same-priority streams: ['Stream_37']
#     Lower-priority streams: ['Stream_15', 'Stream_31']
#     For Stream_37: b_total_H = 1482, l_max_L = 881, r = 125.0, r_total_H = 2.083
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 0, b_j = 995, l_j_min = 995, temp_result = 27.184354645817912
#     d_f = 27.184354645817912
#
# d_f_total for Stream_37: 62.616354645817914
#
# Calculating delay for stream: Stream_38, size: 945, period: 500.0, deadline: 10906.0, pcp: 4
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: ['Stream_37', 'Stream_39']
#     Same-priority streams: ['Stream_38']
#     Lower-priority streams: ['Stream_40']
#     For Stream_38: b_total_H = 1718, l_max_L = 993, r = 125.0, r_total_H = 0.859
#
#     Iterating through same-priority streams:
#         For j = Stream_38: b_C_j = 0, b_j = 945, l_j_min = 945, temp_result = 29.39807122546137
#     d_f = 29.39807122546137
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_27']
#     Same-priority streams: ['Stream_14', 'Stream_38']
#     Lower-priority streams: ['Stream_10']
#     For Stream_38: b_total_H = 719, l_max_L = 817, r = 125.0, r_total_H = 0.719
#
#     Iterating through same-priority streams:
#         For j = Stream_14: b_C_j = 945, b_j = 688, l_j_min = 688, temp_result = 25.4668261761653
#         For j = Stream_38: b_C_j = 688, b_j = 945, l_j_min = 945, temp_result = 25.45493164683258
#     d_f = 25.4668261761653
#
# d_f_total for Stream_38: 54.85300287229395
#
# Calculating delay for stream: Stream_39, size: 723, period: 2000.0, deadline: 16816.0, pcp: 5
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: ['Stream_38', 'Stream_40']
#     For Stream_39: b_total_H = 0, l_max_L = 993, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 723, b_j = 995, l_j_min = 995, temp_result = 21.688
#         For j = Stream_39: b_C_j = 995, b_j = 723, l_j_min = 723, temp_result = 21.688
#     d_f = 21.688
#
#   At hop Switch_5 -> Switch_4, output port 4, link_id Link_15:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: []
#     For Stream_39: b_total_H = 0, l_max_L = 0, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 723, b_j = 995, l_j_min = 995, temp_result = 13.744
#         For j = Stream_39: b_C_j = 995, b_j = 723, l_j_min = 723, temp_result = 13.744
#     d_f = 13.744
#
#   At hop Switch_4 -> Switch_1, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_26']
#     Same-priority streams: ['Stream_39']
#     Lower-priority streams: ['Stream_29', 'Stream_30']
#     For Stream_39: b_total_H = 548, l_max_L = 744, r = 125.0, r_total_H = 1.096
#
#     Iterating through same-priority streams:
#         For j = Stream_39: b_C_j = 0, b_j = 723, l_j_min = 723, temp_result = 16.21142768595041
#     d_f = 16.21142768595041
#
#   At hop Switch_1 -> ES_2, output port 2, link_id Link_2:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_39']
#     Lower-priority streams: ['Stream_13', 'Stream_29']
#     For Stream_39: b_total_H = 0, l_max_L = 762, r = 125.0, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_39: b_C_j = 0, b_j = 723, l_j_min = 723, temp_result = 11.879999999999999
#     d_f = 11.879999999999999
#
# d_f_total for Stream_39: 63.52342768595041
#
# Calculating delay for stream: Stream_40, size: 993, period: 500.0, deadline: 15182.0, pcp: 0
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: ['Stream_37', 'Stream_39', 'Stream_38']
#     Same-priority streams: ['Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 2663, l_max_L = 0, r = 125.0, r_total_H = 2.7489999999999997
#
#     Iterating through same-priority streams:
#         For j = Stream_40: b_C_j = 0, b_j = 993, l_j_min = 993, temp_result = 29.727052899362786
#     d_f = 29.727052899362786
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 1571, l_max_L = 0, r = 125.0, r_total_H = 1.571
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 1541, b_j = 703, l_j_min = 703, temp_result = 30.836875418256646
#         For j = Stream_35: b_C_j = 1696, b_j = 548, l_j_min = 548, temp_result = 30.85265809493717
#         For j = Stream_40: b_C_j = 1251, b_j = 993, l_j_min = 993, temp_result = 30.807346539305996
#     d_f = 30.85265809493717
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 7146, l_max_L = 0, r = 125.0, r_total_H = 8.435500000000001
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 993, b_j = 703, l_j_min = 703, temp_result = 75.44800301978732
#         For j = Stream_40: b_C_j = 703, b_j = 993, l_j_min = 993, temp_result = 75.28011005065865
#     d_f = 75.44800301978732
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_17', 'Stream_30']
#     Same-priority streams: ['Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 4868, l_max_L = 0, r = 125.0, r_total_H = 5.1025
#
#     Iterating through same-priority streams:
#         For j = Stream_40: b_C_j = 0, b_j = 993, l_j_min = 993, temp_result = 48.54534698388207
#     d_f = 48.54534698388207
#
# d_f_total for Stream_40: 184.3598564732095
