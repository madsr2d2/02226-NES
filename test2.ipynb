# %%
import networkx as nx
import csv
import argparse

class Graph:
    def __init__(self):
        # Initialize an empty NetworkX graph
        self.G = nx.Graph()
        self.stream_paths = {}  # Dictionary to store paths for each stream
        # Dictionary to store queue assignments for each output port
        self.queue_assignments = {}

    def load_from_csv(self, topology_file):
        """
        Loads a topology from a CSV file and populates the graph with nodes and edges.

        Args:
            topology_file (str): Path to the topology CSV file.
        """
        devices = []
        links = []

        # Use the csv module to read the file
        with open(topology_file, 'r') as file:
            reader = csv.reader(file)
            for fields in reader:
                if fields[0].lower() == 'es' or fields[0].lower() == 'sw':  # Device entry (SW or ES)
                    devices.append(fields)
                elif fields[0].lower() == 'link':  # Link entry
                    links.append(fields)

        # Add nodes (SW: Switch, ES: End System)
        for device in devices:
            device_type = device[0].strip()
            device_name = device[1].strip()
            self.G.add_node(device_name, type=device_type)

        # Add edges (LINK)
        for link in links:
            link_id = link[1].strip()
            source_device = link[2].strip()
            source_port = int(link[3].strip())
            destination_device = link[4].strip()
            destination_port = int(link[5].strip())

            # Add the edge (link) between source and destination devices, preserving direction information
            self.G.add_edge(
                source_device, destination_device, link_id=link_id,
                source_port=source_port, destination_port=destination_port,
                source_device=source_device, destination_device=destination_device
            )

    def load_streams(self, streams_file):
        """
        Loads stream information from a CSV file.

        Args:
            streams_file (str): Path to the streams CSV file.
        """
        streams = []
        with open(streams_file, 'r') as file:
            reader = csv.reader(file)
            for row in reader:
                streams.append({
                    'pcp': int(row[0]),
                    'name': row[1].strip(),
                    'type': row[2].strip(),
                    'source': row[3].strip(),
                    'destination': row[4].strip(),
                    # TODO: These uint conversions should be handled according to a config file
                    'size': int(row[5])*8, # Convert bytes to bits 
                    'period': float(row[6])*1e-6, # Convert to seconds to be consistent with the r_link which is in bps (period is in us, for now)
                    'deadline': float(row[7])*1e-6 # Convert to seconds to be consistent with the r_link which is in bps (deadline is in us, for now)
                })
        self.streams = streams
        
        # debug print
        # for stream in self.streams:
        #     print(stream)


    def find_shortest_path(self, node_a, node_b):
        """
        Finds the shortest path between two nodes using Dijkstra's algorithm.

        Args:
            node_a (str): The source node.
            node_b (str): The destination node.

        Returns:
            path (list): The shortest path from node_a to node_b as a list of nodes.
        """
        try:
            # Verify that nodes exist in the graph
            if node_a not in self.G or node_b not in self.G:
                print(
                    f"One or both of the nodes ({node_a}, {node_b}) are not in the graph.")
                return None

            # Use Dijkstra's algorithm to find the shortest path without weights
            path = nx.shortest_path(self.G, source=node_a, target=node_b)
            return path
        except nx.NetworkXNoPath:
            print(f"No path exists between {node_a} and {node_b}.")
            return None
        except nx.NodeNotFound:
            print(
                f"One or both of the nodes ({node_a}, {node_b}) are not in the graph.")
            return None

    def calculate_all_paths(self):
        """
        Calculates and stores the shortest paths for all streams, adjusting for the direction of traversal.
        """
        for stream in self.streams:
            source = stream['source']
            destination = stream['destination']
            path = self.find_shortest_path(source, destination)
            if path:
                annotated_path = []
                for i in range(len(path) - 1):
                    current_node = path[i]
                    next_node = path[i + 1]
                    
                    # Get edge data between current node and next node
                    edge_data = self.G.get_edge_data(current_node, next_node)
                    link_id = edge_data['link_id']
                    
                    # Determine direction of traversal and select appropriate ports
                    if current_node == edge_data['source_device']:
                        source_port = edge_data['source_port']
                        destination_port = edge_data['destination_port']
                    else:
                        # If reversed, swap ports
                        source_port = edge_data['destination_port']
                        destination_port = edge_data['source_port']

                    # Annotate the current node details for the path
                    annotated_path.append(f"{current_node}:{link_id}:{source_port}")
                
                # Append final destination node without outgoing link data
                annotated_path.append(f"{destination}")
                
                # Store annotated path in `stream_paths` dictionary
                self.stream_paths[stream['name']] = '->'.join(annotated_path)
                
                # Debug output
                # print(f"{stream['name']} from {source} to {destination}: {self.stream_paths[stream['name']]}")
            else:
                print(f"No path found for Stream {stream['name']} from {source} to {destination}")



    def assign_queues(self):
        """
        Assigns shaped queues for each combination of priority level and upstream source for every output port.
        """
        for stream_name, path in self.stream_paths.items():
            stream = next(s for s in self.streams if s['name'] == stream_name)
            pcp = stream['pcp']
            path_nodes = path.split('->')
            for i in range(len(path_nodes) - 1):
                current_node = path_nodes[i].split(':')[0]
                previous_node = path_nodes[i - 1].split(':')[0] if i > 0 else 'N/A'
                next_node = path_nodes[i + 1].split(':')[0]
                
                # Get edge data between current and next node
                edge_data = self.G.get_edge_data(current_node, next_node)
                
                # Determine output port based on traversal direction
                if current_node == edge_data['source_device']:
                    output_port = edge_data['source_port']
                else:
                    output_port = edge_data['destination_port']

                # Create a queue assignment key for each (current_node, previous_node, output_port, pcp)
                key = (current_node, previous_node, output_port, pcp)

                if key not in self.queue_assignments:
                    self.queue_assignments[key] = []
                self.queue_assignments[key].append(stream_name)


    def compute_worst_case_delay(self, stream_name, verbose=False):
        """
        Computes the worst-case per-hop delay for a stream over its path.

        Args:
            stream_name (str): The name of the stream.

        Returns:
            float: The computed worst-case delay for the stream.
        """
        if stream_name not in self.stream_paths:
            print(f"No path found for stream {stream_name}.")
            return None

        header_size = 0  # Ethernet frame header size
        path = self.stream_paths[stream_name].split('->')
        stream = next(s for s in self.streams if s['name'] == stream_name)
        b = stream['size'] + header_size  # Include Ethernet frame overhead
        r = b / stream['period']
        l_min = b  # Minimum frame size
        r_link = 1000000000  # Assume 1 Gbps link rate for now
        total_delay = 0

        if verbose:
            print(f"\nCalculating delay for stream: {stream_name}, size: {b}, period: {stream['period']}, deadline: {stream['deadline']}, pcp: {stream['pcp']}")

        for i in range(len(path) - 1):
            current_node = path[i].split(':')[0]
            next_node = path[i + 1].split(':')[0]
            edge_data = self.G.get_edge_data(current_node, next_node)

            # Determine output port based on traversal direction
            if current_node == edge_data['source_device']:
                output_port = edge_data['source_port']
            else:
                output_port = edge_data['destination_port']

            # Gather all streams at this output port across priority levels (including current stream)
            all_interfering_streams = [
                s_name for k, streams in self.queue_assignments.items()
                if k[0] == current_node and k[2] == output_port for s_name in streams]

            # Organize interfering streams by priority level relative to `stream['pcp']`
            higher_priority_streams = []
            same_priority_streams = []
            lower_priority_streams = []

            for s_name in all_interfering_streams:
                s_data = next((s for s in self.streams if s['name'] == s_name), None)
                if s_data:
                    if s_data['pcp'] > stream['pcp']:
                        higher_priority_streams.append(s_name)
                    elif s_data['pcp'] == stream['pcp']:
                        same_priority_streams.append(s_name)
                    else:
                        lower_priority_streams.append(s_name)

            # Debug output for all interfering streams organized by priority
            if verbose:
                print(f"  At hop {current_node} -> {next_node}, output port {output_port}, link_id {edge_data['link_id']}:")
                print("    Higher-priority streams:", higher_priority_streams)
                print("    Same-priority streams:", same_priority_streams)
                print("    Lower-priority streams:", lower_priority_streams)

            # Calculate r_H: Total rate of higher-priority streams
            r_H = sum(
                (s_data['size'] + header_size) / s_data['period']
                for s_name in higher_priority_streams
                for s_data in self.streams if s_data['name'] == s_name)

            # Calculate b_H: Total burst size of all higher-priority streams
            b_H = sum(
                (s_data['size'] + header_size) for s_name in higher_priority_streams
                for s_data in self.streams if s_data['name'] == s_name)

            # Calculate l_L: Maximum size of lower-priority streams
            l_L = max(
                [(s_data['size'] + header_size) for s_name in lower_priority_streams
                for s_data in self.streams if s_data['name'] == s_name] or [0])

            # Degug output for r_H, b_H, l_L
            if verbose:
                print(f"    For {stream_name}: b_total_H = {b_H}, l_max_L = {l_L}, r = {r_link}, r_total_H = {r_H}")
                print("\n    Iterating through same-priority streams:")

            # Do eq 10 in the project description
            temp_list = [] # List to store the results of the equation for each same-priority stream
            
            for j in same_priority_streams:
                # Sum burst of all same priority streams excluding stream j
                b_C_j_temp = sum([(s_data['size'] + header_size) for s_name in same_priority_streams if s_name != j for s_data in self.streams if s_data['name'] == s_name])
                
                # Get burst for stream j
                b_j = next((s_data['size'] + header_size for s_data in self.streams if s_data['name'] == j), 0)

                # Get min minimum frame length of stream j (this is just the size of the stream for now...)
                l_j_min = b_j

                try:
                    # Construct the equation and append to the list
                    temp_result = (b_H + b_C_j_temp + (b_j - l_j_min) + l_L) / (r_link - r_H) + (l_j_min / r_link)
                    temp_list.append(temp_result)
                except: 
                    return None
                
                if verbose:
                    print(f"        For j = {j}: b_C_j = {b_C_j_temp}, b_j = {b_j}, l_j_min = {l_j_min}, d_f_temp = {temp_result}")
            
            # Append max of the list to get the worst-case delay
            temp_result = max(temp_list)

            if verbose:
                print(f"    d_f = {temp_result}\n")

            total_delay += temp_result

            # TODO
            #######################################################################################
            # I dont think this is the correct way to calculate b_C_j. Why would we sum the burst of all same-priority interfering streams to get the worst-case scenario?
            # Calculate b_C_j as the sum of burst of any same-priority interfering stream
            # b_C_j = sum(
            #     [(s_data['size'] + header_size) for s_name in same_priority_streams
            #      for s_data in self.streams if s_data['name'] == s_name])

            # Patrick solution
            # temp_list = [(s_data['size'] + header_size) for s_name in same_priority_streams
            #      for s_data in self.streams if s_data['name'] == s_name]
            # # exclude min burst from temp_list
            # if len(temp_list) > 1:
            #     temp_list.remove(min(temp_list))
            # else:
            #     temp_list = [0]
            # b_C_j = sum(temp_list)

            # I think is the correct way to calculate b_C_j. It selects the max burst of the same priority streams, thus ensuring the worst-case scenario. This is same as the eq 10 in the project description. 
            # Calculate b_C_j as the max of burst of any same-priority interfering stream
            # b_C_j = max(
            #     [(s_data['size'] + header_size) for s_name in same_priority_streams
            #      for s_data in self.streams if s_data['name'] == s_name] or [0])
            #######################################################################################

            # Debug output for r_H, b_H, l_L and b_C_j
            # if verbose:
            #     print(f"    Calculated b_H = {b_H}, b_C_j = {b_C_j}, b = {b}, l_min = {l_min}, l_L = {l_L}, r = {r_link}, r_H = {r_H}")

            # Calculate the per-hop delay using the worst-case conditions at this hop
            # try:
            #     per_hop_delay = (b_H + b_C_j + (b - l_min) + l_L) / (r_link - r_H) + (l_min / r_link)
            # except:
            #     return None
            
            # if verbose:
            #     print(f"    Per-hop delay at {current_node} -> {next_node} for stream {stream_name}: {per_hop_delay}")
            
            # total_delay += per_hop_delay

        if verbose:
            print(f"Total delay for stream {stream_name}: {total_delay}")
        # return f'{stream_name}, {round(total_delay*1e6,3)}, {stream["deadline"]}, {self.stream_paths[stream_name]}'
        return total_delay


    def compute_worst_case_delay_for_all_streams(self,topology_file, streams_file, output_file='output.csv', verbose=False):
        """
        Computes the worst-case per-hop delay for all streams over their respective paths.
        """
        # Build the graph
        self.load_from_csv(topology_file)

        # Load streams
        self.load_streams(streams_file)

        # calculate stream paths
        self.calculate_all_paths()

        # assign queues
        self.assign_queues()

        with open(output_file, 'w') as file:
            writer = csv.writer(file)
            writer.writerow('StreamName, MaxE2E(us), Deadline(us), Path'.split(','))
            for stream_name in self.stream_paths.keys():
                wcd = self.compute_worst_case_delay(stream_name,verbose=verbose)
                writer.writerow(f'{stream_name}, {round(wcd*1e6,3)}, {round(next(s_data["deadline"] for s_data in self.streams if s_data["name"] == stream_name)*1e6,3)}, {self.stream_paths[stream_name]}'.split(','))



# Example usage
topology_file = 'topology_willy.csv'  # Replace with your actual file path
streams_file = 'streams_willy.csv'  # Replace with your actual file path

graph = Graph()
graph.compute_worst_case_delay_for_all_streams(topology_file = topology_file, streams_file = streams_file, output_file='output.csv', verbose=True)

# if __name__ == '__main__':
#     # use arogparse to get the file paths
#     parser = argparse.ArgumentParser(description='Compute worst-case delay for all streams')
#     parser.add_argument('--topology_file', '-tf',default='topology.scv', type=str, help='Path to the topology CSV file')
#     parser.add_argument('--streams_file', '-sf', default='streams.csv',type=str, help='Path to the streams CSV file')
#     args = parser.parse_args()

#     # Example usage
#     topology_file = 'topology.csv'  # Replace with your actual file path
#     streams_file = 'streams.csv'  # Replace with your actual file path

#     graph = Graph()
#     graph.compute_worst_case_delay_for_all_streams(topology_file = args.topology_file, streams_file = args.streams_file, output_file='output.csv', verbose=True)
# Out:
# Calculating delay for stream: Stream_1, size: 4816, period: 0.001, deadline: 0.0055439999999999994, pcp: 0
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Same-priority streams: ['Stream_1']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 18008, l_max_L = 0, r = 1000000000, r_total_H = 20812000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 0, b_j = 4816, l_j_min = 4816, d_f_temp = 2.3206748252633815e-05
#     d_f = 2.3206748252633815e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_6', 'Stream_8', 'Stream_26', 'Stream_30']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 41768, l_max_L = 0, r = 1000000000, r_total_H = 56468000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 7928, b_j = 4816, l_j_min = 4816, d_f_temp = 5.748617970773646e-05
#         For j = Stream_5: b_C_j = 4816, b_j = 7928, l_j_min = 7928, d_f_temp = 5.7299934391202414e-05
#     d_f = 5.748617970773646e-05
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_16', 'Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_1: b_total_H = 19752, l_max_L = 0, r = 1000000000, r_total_H = 28152000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 7928, b_j = 4816, l_j_min = 4816, d_f_temp = 3.329782020233617e-05
#         For j = Stream_5: b_C_j = 4816, b_j = 7928, l_j_min = 7928, d_f_temp = 3.320767336455907e-05
#     d_f = 3.329782020233617e-05
#
# Total delay for stream Stream_1: 0.00011399074816270644
#
# Calculating delay for stream: Stream_2, size: 5736, period: 0.002, deadline: 0.009538, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_2: b_total_H = 0, l_max_L = 4816, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 12272, b_j = 5736, l_j_min = 5736, d_f_temp = 2.2824e-05
#         For j = Stream_3: b_C_j = 13608, b_j = 4400, l_j_min = 4400, d_f_temp = 2.2823999999999997e-05
#         For j = Stream_4: b_C_j = 10136, b_j = 7872, l_j_min = 7872, d_f_temp = 2.2824e-05
#     d_f = 2.2824e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_2: b_total_H = 11896, l_max_L = 7928, r = 1000000000, r_total_H = 23792000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 19064, b_j = 5736, l_j_min = 5736, d_f_temp = 4.55717727041778e-05
#         For j = Stream_3: b_C_j = 20400, b_j = 4400, l_j_min = 4400, d_f_temp = 4.560433350269615e-05
#         For j = Stream_4: b_C_j = 16928, b_j = 7872, l_j_min = 7872, d_f_temp = 4.5519714421516726e-05
#         For j = Stream_8: b_C_j = 18008, b_j = 6792, l_j_min = 6792, d_f_temp = 4.55460360251094e-05
#     d_f = 4.560433350269615e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_2: b_total_H = 13048, l_max_L = 7944, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 26280, b_j = 5736, l_j_min = 5736, d_f_temp = 5.400031430205015e-05
#         For j = Stream_3: b_C_j = 27616, b_j = 4400, l_j_min = 4400, d_f_temp = 5.4028359062321324e-05
#         For j = Stream_4: b_C_j = 24144, b_j = 7872, l_j_min = 7872, d_f_temp = 5.395547627215552e-05
#         For j = Stream_8: b_C_j = 25224, b_j = 6792, l_j_min = 6792, d_f_temp = 5.3978147186147185e-05
#         For j = Stream_9: b_C_j = 24800, b_j = 7216, l_j_min = 7216, d_f_temp = 5.396924675324675e-05
#     d_f = 5.4028359062321324e-05
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2']
#     Lower-priority streams: ['Stream_33', 'Stream_34']
#     For Stream_2: b_total_H = 13048, l_max_L = 7032, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 0, b_j = 5736, l_j_min = 5736, d_f_temp = 2.6237511067548805e-05
#     d_f = 2.6237511067548805e-05
#
# Total delay for stream Stream_2: 0.00014869420363256626
#
# Calculating delay for stream: Stream_3, size: 4400, period: 0.002, deadline: 0.002634, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_3: b_total_H = 0, l_max_L = 4816, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 12272, b_j = 5736, l_j_min = 5736, d_f_temp = 2.2824e-05
#         For j = Stream_3: b_C_j = 13608, b_j = 4400, l_j_min = 4400, d_f_temp = 2.2823999999999997e-05
#         For j = Stream_4: b_C_j = 10136, b_j = 7872, l_j_min = 7872, d_f_temp = 2.2824e-05
#     d_f = 2.2824e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_3: b_total_H = 11896, l_max_L = 7928, r = 1000000000, r_total_H = 23792000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 19064, b_j = 5736, l_j_min = 5736, d_f_temp = 4.55717727041778e-05
#         For j = Stream_3: b_C_j = 20400, b_j = 4400, l_j_min = 4400, d_f_temp = 4.560433350269615e-05
#         For j = Stream_4: b_C_j = 16928, b_j = 7872, l_j_min = 7872, d_f_temp = 4.5519714421516726e-05
#         For j = Stream_8: b_C_j = 18008, b_j = 6792, l_j_min = 6792, d_f_temp = 4.55460360251094e-05
#     d_f = 4.560433350269615e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_3: b_total_H = 13048, l_max_L = 7944, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 26280, b_j = 5736, l_j_min = 5736, d_f_temp = 5.400031430205015e-05
#         For j = Stream_3: b_C_j = 27616, b_j = 4400, l_j_min = 4400, d_f_temp = 5.4028359062321324e-05
#         For j = Stream_4: b_C_j = 24144, b_j = 7872, l_j_min = 7872, d_f_temp = 5.395547627215552e-05
#         For j = Stream_8: b_C_j = 25224, b_j = 6792, l_j_min = 6792, d_f_temp = 5.3978147186147185e-05
#         For j = Stream_9: b_C_j = 24800, b_j = 7216, l_j_min = 7216, d_f_temp = 5.396924675324675e-05
#     d_f = 5.4028359062321324e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_3: b_total_H = 7592, l_max_L = 7944, r = 1000000000, r_total_H = 3796000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 21880, b_j = 4400, l_j_min = 4400, d_f_temp = 4.195857234060494e-05
#         For j = Stream_4: b_C_j = 18408, b_j = 7872, l_j_min = 7872, d_f_temp = 4.194534240777994e-05
#         For j = Stream_8: b_C_j = 19488, b_j = 6792, l_j_min = 6792, d_f_temp = 4.194945770946513e-05
#         For j = Stream_9: b_C_j = 19064, b_j = 7216, l_j_min = 7216, d_f_temp = 4.194784207250724e-05
#     d_f = 4.195857234060494e-05
#
# Total delay for stream Stream_3: 0.0001644152649056224
#
# Calculating delay for stream: Stream_4, size: 7872, period: 0.0005, deadline: 0.016975999999999998, pcp: 3
#   At hop ES_1 -> Switch_1, output port 1, link_id Link_1:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4']
#     Lower-priority streams: ['Stream_1']
#     For Stream_4: b_total_H = 0, l_max_L = 4816, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 12272, b_j = 5736, l_j_min = 5736, d_f_temp = 2.2824e-05
#         For j = Stream_3: b_C_j = 13608, b_j = 4400, l_j_min = 4400, d_f_temp = 2.2823999999999997e-05
#         For j = Stream_4: b_C_j = 10136, b_j = 7872, l_j_min = 7872, d_f_temp = 2.2824e-05
#     d_f = 2.2824e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_4: b_total_H = 11896, l_max_L = 7928, r = 1000000000, r_total_H = 23792000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 19064, b_j = 5736, l_j_min = 5736, d_f_temp = 4.55717727041778e-05
#         For j = Stream_3: b_C_j = 20400, b_j = 4400, l_j_min = 4400, d_f_temp = 4.560433350269615e-05
#         For j = Stream_4: b_C_j = 16928, b_j = 7872, l_j_min = 7872, d_f_temp = 4.5519714421516726e-05
#         For j = Stream_8: b_C_j = 18008, b_j = 6792, l_j_min = 6792, d_f_temp = 4.55460360251094e-05
#     d_f = 4.560433350269615e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_4: b_total_H = 13048, l_max_L = 7944, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 26280, b_j = 5736, l_j_min = 5736, d_f_temp = 5.400031430205015e-05
#         For j = Stream_3: b_C_j = 27616, b_j = 4400, l_j_min = 4400, d_f_temp = 5.4028359062321324e-05
#         For j = Stream_4: b_C_j = 24144, b_j = 7872, l_j_min = 7872, d_f_temp = 5.395547627215552e-05
#         For j = Stream_8: b_C_j = 25224, b_j = 6792, l_j_min = 6792, d_f_temp = 5.3978147186147185e-05
#         For j = Stream_9: b_C_j = 24800, b_j = 7216, l_j_min = 7216, d_f_temp = 5.396924675324675e-05
#     d_f = 5.4028359062321324e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_4: b_total_H = 7592, l_max_L = 7944, r = 1000000000, r_total_H = 3796000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 21880, b_j = 4400, l_j_min = 4400, d_f_temp = 4.195857234060494e-05
#         For j = Stream_4: b_C_j = 18408, b_j = 7872, l_j_min = 7872, d_f_temp = 4.194534240777994e-05
#         For j = Stream_8: b_C_j = 19488, b_j = 6792, l_j_min = 6792, d_f_temp = 4.194945770946513e-05
#         For j = Stream_9: b_C_j = 19064, b_j = 7216, l_j_min = 7216, d_f_temp = 4.194784207250724e-05
#     d_f = 4.195857234060494e-05
#
# Total delay for stream Stream_4: 0.0001644152649056224
#
# Calculating delay for stream: Stream_5, size: 7928, period: 0.001, deadline: 0.018281, pcp: 0
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6', 'Stream_7', 'Stream_8']
#     Same-priority streams: ['Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 21584, l_max_L = 0, r = 1000000000, r_total_H = 36376000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_5: b_C_j = 0, b_j = 7928, l_j_min = 7928, d_f_temp = 3.0326777946584973e-05
#     d_f = 3.0326777946584973e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_6', 'Stream_8', 'Stream_26', 'Stream_30']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 41768, l_max_L = 0, r = 1000000000, r_total_H = 56468000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 7928, b_j = 4816, l_j_min = 4816, d_f_temp = 5.748617970773646e-05
#         For j = Stream_5: b_C_j = 4816, b_j = 7928, l_j_min = 7928, d_f_temp = 5.7299934391202414e-05
#     d_f = 5.748617970773646e-05
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_16', 'Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_1', 'Stream_5']
#     Lower-priority streams: []
#     For Stream_5: b_total_H = 19752, l_max_L = 0, r = 1000000000, r_total_H = 28152000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_1: b_C_j = 7928, b_j = 4816, l_j_min = 4816, d_f_temp = 3.329782020233617e-05
#         For j = Stream_5: b_C_j = 4816, b_j = 7928, l_j_min = 7928, d_f_temp = 3.320767336455907e-05
#     d_f = 3.329782020233617e-05
#
# Total delay for stream Stream_5: 0.0001211107778566576
#
# Calculating delay for stream: Stream_6, size: 7512, period: 0.0005, deadline: 0.019211, pcp: 6
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_5', 'Stream_7', 'Stream_8']
#     For Stream_6: b_total_H = 0, l_max_L = 7928, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 7512, l_j_min = 7512, d_f_temp = 1.544e-05
#     d_f = 1.544e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6', 'Stream_26']
#     Lower-priority streams: ['Stream_1', 'Stream_2', 'Stream_3', 'Stream_4', 'Stream_5', 'Stream_8', 'Stream_30']
#     For Stream_6: b_total_H = 0, l_max_L = 7928, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 4384, b_j = 7512, l_j_min = 7512, d_f_temp = 1.9824e-05
#         For j = Stream_26: b_C_j = 7512, b_j = 4384, l_j_min = 4384, d_f_temp = 1.9824000000000002e-05
#     d_f = 1.9824000000000002e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_34', 'Stream_40', 'Stream_36']
#     For Stream_6: b_total_H = 0, l_max_L = 7944, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 7512, l_j_min = 7512, d_f_temp = 1.5456000000000002e-05
#     d_f = 1.5456000000000002e-05
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_6']
#     Lower-priority streams: ['Stream_2', 'Stream_33', 'Stream_34', 'Stream_36']
#     For Stream_6: b_total_H = 0, l_max_L = 7032, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_6: b_C_j = 0, b_j = 7512, l_j_min = 7512, d_f_temp = 1.4544e-05
#     d_f = 1.4544e-05
#
# Total delay for stream Stream_6: 6.5264e-05
#
# Calculating delay for stream: Stream_7, size: 7280, period: 0.0005, deadline: 0.003915, pcp: 2
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6', 'Stream_8']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: ['Stream_5']
#     For Stream_7: b_total_H = 14304, l_max_L = 7928, r = 1000000000, r_total_H = 21816000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 7280, l_j_min = 7280, d_f_temp = 3.000783034684681e-05
#     d_f = 3.000783034684681e-05
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_11', 'Stream_15', 'Stream_19', 'Stream_20', 'Stream_24']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: []
#     For Stream_7: b_total_H = 30384, l_max_L = 0, r = 1000000000, r_total_H = 43148000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 7280, l_j_min = 7280, d_f_temp = 3.9034127075033546e-05
#     d_f = 3.9034127075033546e-05
#
#   At hop Switch_4 -> ES_8, output port 2, link_id Link_8:
#     Higher-priority streams: ['Stream_19', 'Stream_24']
#     Same-priority streams: ['Stream_7']
#     Lower-priority streams: []
#     For Stream_7: b_total_H = 11480, l_max_L = 0, r = 1000000000, r_total_H = 22960000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_7: b_C_j = 0, b_j = 7280, l_j_min = 7280, d_f_temp = 1.9029774830099072e-05
#     d_f = 1.9029774830099072e-05
#
# Total delay for stream Stream_7: 8.807173225197942e-05
#
# Calculating delay for stream: Stream_8, size: 6792, period: 0.001, deadline: 0.016436, pcp: 3
#   At hop ES_2 -> Switch_1, output port 1, link_id Link_2:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_8']
#     Lower-priority streams: ['Stream_5', 'Stream_7']
#     For Stream_8: b_total_H = 7512, l_max_L = 7928, r = 1000000000, r_total_H = 15024000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_8: b_C_j = 0, b_j = 6792, l_j_min = 6792, d_f_temp = 2.246750884488556e-05
#     d_f = 2.246750884488556e-05
#
#   At hop Switch_1 -> Switch_2, output port 4, link_id Link_12:
#     Higher-priority streams: ['Stream_6', 'Stream_26']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_30']
#     For Stream_8: b_total_H = 11896, l_max_L = 7928, r = 1000000000, r_total_H = 23792000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 19064, b_j = 5736, l_j_min = 5736, d_f_temp = 4.55717727041778e-05
#         For j = Stream_3: b_C_j = 20400, b_j = 4400, l_j_min = 4400, d_f_temp = 4.560433350269615e-05
#         For j = Stream_4: b_C_j = 16928, b_j = 7872, l_j_min = 7872, d_f_temp = 4.5519714421516726e-05
#         For j = Stream_8: b_C_j = 18008, b_j = 6792, l_j_min = 6792, d_f_temp = 4.55460360251094e-05
#     d_f = 4.560433350269615e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_8: b_total_H = 13048, l_max_L = 7944, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 26280, b_j = 5736, l_j_min = 5736, d_f_temp = 5.400031430205015e-05
#         For j = Stream_3: b_C_j = 27616, b_j = 4400, l_j_min = 4400, d_f_temp = 5.4028359062321324e-05
#         For j = Stream_4: b_C_j = 24144, b_j = 7872, l_j_min = 7872, d_f_temp = 5.395547627215552e-05
#         For j = Stream_8: b_C_j = 25224, b_j = 6792, l_j_min = 6792, d_f_temp = 5.3978147186147185e-05
#         For j = Stream_9: b_C_j = 24800, b_j = 7216, l_j_min = 7216, d_f_temp = 5.396924675324675e-05
#     d_f = 5.4028359062321324e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_8: b_total_H = 7592, l_max_L = 7944, r = 1000000000, r_total_H = 3796000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 21880, b_j = 4400, l_j_min = 4400, d_f_temp = 4.195857234060494e-05
#         For j = Stream_4: b_C_j = 18408, b_j = 7872, l_j_min = 7872, d_f_temp = 4.194534240777994e-05
#         For j = Stream_8: b_C_j = 19488, b_j = 6792, l_j_min = 6792, d_f_temp = 4.194945770946513e-05
#         For j = Stream_9: b_C_j = 19064, b_j = 7216, l_j_min = 7216, d_f_temp = 4.194784207250724e-05
#     d_f = 4.195857234060494e-05
#
# Total delay for stream Stream_8: 0.00016405877375050797
#
# Calculating delay for stream: Stream_9, size: 7216, period: 0.001, deadline: 0.015562, pcp: 3
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_11', 'Stream_12']
#     Same-priority streams: ['Stream_9']
#     Lower-priority streams: ['Stream_10']
#     For Stream_9: b_total_H = 10312, l_max_L = 6536, r = 1000000000, r_total_H = 15120000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_9: b_C_j = 0, b_j = 7216, l_j_min = 7216, d_f_temp = 2.4322652587117213e-05
#     d_f = 2.4322652587117213e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_9: b_total_H = 13048, l_max_L = 7944, r = 1000000000, r_total_H = 20560000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_2: b_C_j = 26280, b_j = 5736, l_j_min = 5736, d_f_temp = 5.400031430205015e-05
#         For j = Stream_3: b_C_j = 27616, b_j = 4400, l_j_min = 4400, d_f_temp = 5.4028359062321324e-05
#         For j = Stream_4: b_C_j = 24144, b_j = 7872, l_j_min = 7872, d_f_temp = 5.395547627215552e-05
#         For j = Stream_8: b_C_j = 25224, b_j = 6792, l_j_min = 6792, d_f_temp = 5.3978147186147185e-05
#         For j = Stream_9: b_C_j = 24800, b_j = 7216, l_j_min = 7216, d_f_temp = 5.396924675324675e-05
#     d_f = 5.4028359062321324e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_17']
#     Same-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9']
#     Lower-priority streams: ['Stream_30', 'Stream_40']
#     For Stream_9: b_total_H = 7592, l_max_L = 7944, r = 1000000000, r_total_H = 3796000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_3: b_C_j = 21880, b_j = 4400, l_j_min = 4400, d_f_temp = 4.195857234060494e-05
#         For j = Stream_4: b_C_j = 18408, b_j = 7872, l_j_min = 7872, d_f_temp = 4.194534240777994e-05
#         For j = Stream_8: b_C_j = 19488, b_j = 6792, l_j_min = 6792, d_f_temp = 4.194945770946513e-05
#         For j = Stream_9: b_C_j = 19064, b_j = 7216, l_j_min = 7216, d_f_temp = 4.194784207250724e-05
#     d_f = 4.195857234060494e-05
#
# Total delay for stream Stream_9: 0.00012030958399004347
#
# Calculating delay for stream: Stream_10, size: 6536, period: 0.001, deadline: 0.018068999999999998, pcp: 1
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_9', 'Stream_11', 'Stream_12']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 17528, l_max_L = 0, r = 1000000000, r_total_H = 22336000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 6536, l_j_min = 6536, d_f_temp = 2.4464449855983243e-05
#     d_f = 2.4464449855983243e-05
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: ['Stream_12', 'Stream_14']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 11008, l_max_L = 0, r = 1000000000, r_total_H = 8256000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 6536, l_j_min = 6536, d_f_temp = 1.763563861641714e-05
#     d_f = 1.763563861641714e-05
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_14', 'Stream_27', 'Stream_38']
#     Same-priority streams: ['Stream_10']
#     Lower-priority streams: []
#     For Stream_10: b_total_H = 18816, l_max_L = 0, r = 1000000000, r_total_H = 23624000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_10: b_C_j = 0, b_j = 6536, l_j_min = 6536, d_f_temp = 2.580726434898031e-05
#     d_f = 2.580726434898031e-05
#
# Total delay for stream Stream_10: 6.790735282138068e-05
#
# Calculating delay for stream: Stream_11, size: 4808, period: 0.0005, deadline: 0.012905999999999999, pcp: 6
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_9', 'Stream_10', 'Stream_12']
#     For Stream_11: b_total_H = 0, l_max_L = 7216, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 4808, l_j_min = 4808, d_f_temp = 1.2024e-05
#     d_f = 1.2024e-05
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_11: b_total_H = 13008, l_max_L = 7048, r = 1000000000, r_total_H = 18968000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 4808, l_j_min = 4808, d_f_temp = 2.5251777573004756e-05
#     d_f = 2.5251777573004756e-05
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_7', 'Stream_15', 'Stream_24']
#     For Stream_11: b_total_H = 13008, l_max_L = 7280, r = 1000000000, r_total_H = 18968000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 4808, l_j_min = 4808, d_f_temp = 2.5488263233003615e-05
#     d_f = 2.5488263233003615e-05
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_20']
#     Same-priority streams: ['Stream_11']
#     Lower-priority streams: ['Stream_15', 'Stream_31', 'Stream_37']
#     For Stream_11: b_total_H = 7048, l_max_L = 7960, r = 1000000000, r_total_H = 7048000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_11: b_C_j = 0, b_j = 4808, l_j_min = 4808, d_f_temp = 1.9922527187618335e-05
#     d_f = 1.9922527187618335e-05
#
# Total delay for stream Stream_11: 8.268656799362672e-05
#
# Calculating delay for stream: Stream_12, size: 5504, period: 0.001, deadline: 0.001795, pcp: 4
#   At hop ES_3 -> Switch_2, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_11']
#     Same-priority streams: ['Stream_12']
#     Lower-priority streams: ['Stream_9', 'Stream_10']
#     For Stream_12: b_total_H = 4808, l_max_L = 7216, r = 1000000000, r_total_H = 9616000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 0, b_j = 5504, l_j_min = 5504, d_f_temp = 1.7644745407841807e-05
#     d_f = 1.7644745407841807e-05
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_14']
#     Lower-priority streams: ['Stream_10']
#     For Stream_12: b_total_H = 0, l_max_L = 6536, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 5504, b_j = 5504, l_j_min = 5504, d_f_temp = 1.7544e-05
#         For j = Stream_14: b_C_j = 5504, b_j = 5504, l_j_min = 5504, d_f_temp = 1.7544e-05
#     d_f = 1.7544e-05
#
#   At hop Switch_5 -> ES_10, output port 2, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_32']
#     Lower-priority streams: ['Stream_25', 'Stream_28']
#     For Stream_12: b_total_H = 0, l_max_L = 7096, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 4088, b_j = 5504, l_j_min = 5504, d_f_temp = 1.6688e-05
#         For j = Stream_32: b_C_j = 5504, b_j = 4088, l_j_min = 4088, d_f_temp = 1.6688e-05
#     d_f = 1.6688e-05
#
# Total delay for stream Stream_12: 5.1876745407841804e-05
#
# Calculating delay for stream: Stream_13, size: 6096, period: 0.0005, deadline: 0.019237, pcp: 4
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_16']
#     Same-priority streams: ['Stream_13', 'Stream_14']
#     Lower-priority streams: ['Stream_15']
#     For Stream_13: b_total_H = 7568, l_max_L = 7048, r = 1000000000, r_total_H = 3784000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 5504, b_j = 6096, l_j_min = 6096, d_f_temp = 2.629242326563717e-05
#         For j = Stream_14: b_C_j = 6096, b_j = 5504, l_j_min = 5504, d_f_temp = 2.629467190247898e-05
#     d_f = 2.629467190247898e-05
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_11', 'Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_13', 'Stream_23', 'Stream_24']
#     Lower-priority streams: ['Stream_15']
#     For Stream_13: b_total_H = 17816, l_max_L = 7048, r = 1000000000, r_total_H = 28584000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 10592, b_j = 6096, l_j_min = 6096, d_f_temp = 4.259529587324071e-05
#         For j = Stream_23: b_C_j = 11616, b_j = 5072, l_j_min = 5072, d_f_temp = 4.262542716199857e-05
#         For j = Stream_24: b_C_j = 11168, b_j = 5520, l_j_min = 5520, d_f_temp = 4.261224472316701e-05
#     d_f = 4.262542716199857e-05
#
#   At hop Switch_1 -> ES_2, output port 2, link_id Link_2:
#     Higher-priority streams: ['Stream_39']
#     Same-priority streams: ['Stream_13']
#     Lower-priority streams: ['Stream_29']
#     For Stream_13: b_total_H = 5784, l_max_L = 5952, r = 1000000000, r_total_H = 2892000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 0, b_j = 6096, l_j_min = 6096, d_f_temp = 1.7866038952651066e-05
#     d_f = 1.7866038952651066e-05
#
# Total delay for stream Stream_13: 8.678613801712862e-05
#
# Calculating delay for stream: Stream_14, size: 5504, period: 0.002, deadline: 0.003946, pcp: 4
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_16']
#     Same-priority streams: ['Stream_13', 'Stream_14']
#     Lower-priority streams: ['Stream_15']
#     For Stream_14: b_total_H = 7568, l_max_L = 7048, r = 1000000000, r_total_H = 3784000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_13: b_C_j = 5504, b_j = 6096, l_j_min = 6096, d_f_temp = 2.629242326563717e-05
#         For j = Stream_14: b_C_j = 6096, b_j = 5504, l_j_min = 5504, d_f_temp = 2.629467190247898e-05
#     d_f = 2.629467190247898e-05
#
#   At hop Switch_2 -> Switch_5, output port 4, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_12', 'Stream_14']
#     Lower-priority streams: ['Stream_10']
#     For Stream_14: b_total_H = 0, l_max_L = 6536, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_12: b_C_j = 5504, b_j = 5504, l_j_min = 5504, d_f_temp = 1.7544e-05
#         For j = Stream_14: b_C_j = 5504, b_j = 5504, l_j_min = 5504, d_f_temp = 1.7544e-05
#     d_f = 1.7544e-05
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_27']
#     Same-priority streams: ['Stream_14', 'Stream_38']
#     Lower-priority streams: ['Stream_10']
#     For Stream_14: b_total_H = 5752, l_max_L = 6536, r = 1000000000, r_total_H = 5752000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_14: b_C_j = 7560, b_j = 5504, l_j_min = 5504, d_f_temp = 2.5466826176165302e-05
#         For j = Stream_38: b_C_j = 5504, b_j = 7560, l_j_min = 7560, d_f_temp = 2.545493164683258e-05
#     d_f = 2.5466826176165302e-05
#
# Total delay for stream Stream_14: 6.930549807864428e-05
#
# Calculating delay for stream: Stream_15, size: 7048, period: 0.002, deadline: 0.008364, pcp: 3
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: ['Stream_13', 'Stream_14', 'Stream_16']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: []
#     For Stream_15: b_total_H = 19168, l_max_L = 0, r = 1000000000, r_total_H = 18728000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 7048, l_j_min = 7048, d_f_temp = 2.6581829559999675e-05
#     d_f = 2.6581829559999675e-05
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: ['Stream_11', 'Stream_13', 'Stream_19', 'Stream_20', 'Stream_23', 'Stream_24']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: []
#     For Stream_15: b_total_H = 34504, l_max_L = 0, r = 1000000000, r_total_H = 56888000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 7048, l_j_min = 7048, d_f_temp = 4.363326240785824e-05
#     d_f = 4.363326240785824e-05
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_11', 'Stream_19', 'Stream_20', 'Stream_24']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: ['Stream_7']
#     For Stream_15: b_total_H = 23336, l_max_L = 7280, r = 1000000000, r_total_H = 39624000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 7048, l_j_min = 7048, d_f_temp = 3.892718065424375e-05
#     d_f = 3.892718065424375e-05
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_11', 'Stream_20', 'Stream_37']
#     Same-priority streams: ['Stream_15']
#     Lower-priority streams: ['Stream_31']
#     For Stream_15: b_total_H = 19816, l_max_L = 4312, r = 1000000000, r_total_H = 20644000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_15: b_C_j = 0, b_j = 7048, l_j_min = 7048, d_f_temp = 3.168459792761774e-05
#     d_f = 3.168459792761774e-05
#
# Total delay for stream Stream_15: 0.0001408268705497194
#
# Calculating delay for stream: Stream_16, size: 7568, period: 0.002, deadline: 0.016124, pcp: 5
#   At hop ES_4 -> Switch_2, output port 1, link_id Link_4:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_16']
#     Lower-priority streams: ['Stream_13', 'Stream_14', 'Stream_15']
#     For Stream_16: b_total_H = 0, l_max_L = 7048, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_16: b_C_j = 0, b_j = 7568, l_j_min = 7568, d_f_temp = 1.4616e-05
#     d_f = 1.4616e-05
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: ['Stream_18', 'Stream_26']
#     Same-priority streams: ['Stream_16']
#     Lower-priority streams: ['Stream_1', 'Stream_5']
#     For Stream_16: b_total_H = 12184, l_max_L = 7928, r = 1000000000, r_total_H = 24368000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_16: b_C_j = 0, b_j = 7568, l_j_min = 7568, d_f_temp = 2.8182329993276152e-05
#     d_f = 2.8182329993276152e-05
#
# Total delay for stream Stream_16: 4.279832999327615e-05
#
# Calculating delay for stream: Stream_17, size: 7592, period: 0.002, deadline: 0.008418, pcp: 4
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Same-priority streams: ['Stream_17']
#     Lower-priority streams: []
#     For Stream_17: b_total_H = 20808, l_max_L = 0, r = 1000000000, r_total_H = 34568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_17: b_C_j = 0, b_j = 7592, l_j_min = 7592, d_f_temp = 2.914504568317603e-05
#     d_f = 2.914504568317603e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_17']
#     Lower-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_40']
#     For Stream_17: b_total_H = 0, l_max_L = 7944, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_17: b_C_j = 0, b_j = 7592, l_j_min = 7592, d_f_temp = 1.5536e-05
#     d_f = 1.5536e-05
#
# Total delay for stream Stream_17: 4.4681045683176034e-05
#
# Calculating delay for stream: Stream_18, size: 7800, period: 0.0005, deadline: 0.011136, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_18: b_total_H = 0, l_max_L = 7592, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 13008, b_j = 7800, l_j_min = 7800, d_f_temp = 2.84e-05
#         For j = Stream_19: b_C_j = 14848, b_j = 5960, l_j_min = 5960, d_f_temp = 2.84e-05
#         For j = Stream_20: b_C_j = 13760, b_j = 7048, l_j_min = 7048, d_f_temp = 2.8400000000000003e-05
#     d_f = 2.8400000000000003e-05
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_18: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 24192, b_j = 7800, l_j_min = 7800, d_f_temp = 3.7512e-05
#         For j = Stream_19: b_C_j = 26032, b_j = 5960, l_j_min = 5960, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_20: b_C_j = 24944, b_j = 7048, l_j_min = 7048, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_21: b_C_j = 27784, b_j = 4208, l_j_min = 4208, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_22: b_C_j = 25016, b_j = 6976, l_j_min = 6976, d_f_temp = 3.7512e-05
#     d_f = 3.7512e-05
#
#   At hop Switch_2 -> ES_3, output port 1, link_id Link_3:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18']
#     Lower-priority streams: ['Stream_1', 'Stream_5', 'Stream_16', 'Stream_26']
#     For Stream_18: b_total_H = 0, l_max_L = 7928, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 0, b_j = 7800, l_j_min = 7800, d_f_temp = 1.5728e-05
#     d_f = 1.5728e-05
#
# Total delay for stream Stream_18: 8.164e-05
#
# Calculating delay for stream: Stream_19, size: 5960, period: 0.0005, deadline: 0.004352, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_19: b_total_H = 0, l_max_L = 7592, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 13008, b_j = 7800, l_j_min = 7800, d_f_temp = 2.84e-05
#         For j = Stream_19: b_C_j = 14848, b_j = 5960, l_j_min = 5960, d_f_temp = 2.84e-05
#         For j = Stream_20: b_C_j = 13760, b_j = 7048, l_j_min = 7048, d_f_temp = 2.8400000000000003e-05
#     d_f = 2.8400000000000003e-05
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 24192, b_j = 7800, l_j_min = 7800, d_f_temp = 3.7512e-05
#         For j = Stream_19: b_C_j = 26032, b_j = 5960, l_j_min = 5960, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_20: b_C_j = 24944, b_j = 7048, l_j_min = 7048, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_21: b_C_j = 27784, b_j = 4208, l_j_min = 4208, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_22: b_C_j = 25016, b_j = 6976, l_j_min = 6976, d_f_temp = 3.7512e-05
#     d_f = 3.7512e-05
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 7048, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 7048, b_j = 5960, l_j_min = 5960, d_f_temp = 2.0056e-05
#         For j = Stream_20: b_C_j = 5960, b_j = 7048, l_j_min = 7048, d_f_temp = 2.0056e-05
#     d_f = 2.0056e-05
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_7', 'Stream_11', 'Stream_15', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 7280, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 7048, b_j = 5960, l_j_min = 5960, d_f_temp = 2.0288e-05
#         For j = Stream_20: b_C_j = 5960, b_j = 7048, l_j_min = 7048, d_f_temp = 2.0288e-05
#     d_f = 2.0288e-05
#
#   At hop Switch_4 -> ES_8, output port 2, link_id Link_8:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19']
#     Lower-priority streams: ['Stream_7', 'Stream_24']
#     For Stream_19: b_total_H = 0, l_max_L = 7280, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 0, b_j = 5960, l_j_min = 5960, d_f_temp = 1.3239999999999999e-05
#     d_f = 1.3239999999999999e-05
#
# Total delay for stream Stream_19: 0.000119496
#
# Calculating delay for stream: Stream_20, size: 7048, period: 0.001, deadline: 0.00997, pcp: 7
#   At hop ES_5 -> Switch_3, output port 1, link_id Link_5:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_17']
#     For Stream_20: b_total_H = 0, l_max_L = 7592, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 13008, b_j = 7800, l_j_min = 7800, d_f_temp = 2.84e-05
#         For j = Stream_19: b_C_j = 14848, b_j = 5960, l_j_min = 5960, d_f_temp = 2.84e-05
#         For j = Stream_20: b_C_j = 13760, b_j = 7048, l_j_min = 7048, d_f_temp = 2.8400000000000003e-05
#     d_f = 2.8400000000000003e-05
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 24192, b_j = 7800, l_j_min = 7800, d_f_temp = 3.7512e-05
#         For j = Stream_19: b_C_j = 26032, b_j = 5960, l_j_min = 5960, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_20: b_C_j = 24944, b_j = 7048, l_j_min = 7048, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_21: b_C_j = 27784, b_j = 4208, l_j_min = 4208, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_22: b_C_j = 25016, b_j = 6976, l_j_min = 6976, d_f_temp = 3.7512e-05
#     d_f = 3.7512e-05
#
#   At hop Switch_2 -> Switch_1, output port 3, link_id Link_12:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_13', 'Stream_15', 'Stream_23', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 7048, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 7048, b_j = 5960, l_j_min = 5960, d_f_temp = 2.0056e-05
#         For j = Stream_20: b_C_j = 5960, b_j = 7048, l_j_min = 7048, d_f_temp = 2.0056e-05
#     d_f = 2.0056e-05
#
#   At hop Switch_1 -> Switch_4, output port 3, link_id Link_11:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_19', 'Stream_20']
#     Lower-priority streams: ['Stream_7', 'Stream_11', 'Stream_15', 'Stream_24']
#     For Stream_20: b_total_H = 0, l_max_L = 7280, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_19: b_C_j = 7048, b_j = 5960, l_j_min = 5960, d_f_temp = 2.0288e-05
#         For j = Stream_20: b_C_j = 5960, b_j = 7048, l_j_min = 7048, d_f_temp = 2.0288e-05
#     d_f = 2.0288e-05
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_20']
#     Lower-priority streams: ['Stream_11', 'Stream_15', 'Stream_31', 'Stream_37']
#     For Stream_20: b_total_H = 0, l_max_L = 7960, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_20: b_C_j = 0, b_j = 7048, l_j_min = 7048, d_f_temp = 1.5008e-05
#     d_f = 1.5008e-05
#
# Total delay for stream Stream_20: 0.000121264
#
# Calculating delay for stream: Stream_21, size: 4208, period: 0.0005, deadline: 0.009733, pcp: 7
#   At hop ES_6 -> Switch_3, output port 1, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_21: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 6976, b_j = 4208, l_j_min = 4208, d_f_temp = 1.6704e-05
#         For j = Stream_22: b_C_j = 4208, b_j = 6976, l_j_min = 6976, d_f_temp = 1.6704e-05
#     d_f = 1.6704e-05
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_21: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 24192, b_j = 7800, l_j_min = 7800, d_f_temp = 3.7512e-05
#         For j = Stream_19: b_C_j = 26032, b_j = 5960, l_j_min = 5960, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_20: b_C_j = 24944, b_j = 7048, l_j_min = 7048, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_21: b_C_j = 27784, b_j = 4208, l_j_min = 4208, d_f_temp = 3.7511999999999996e-05
#         For j = Stream_22: b_C_j = 25016, b_j = 6976, l_j_min = 6976, d_f_temp = 3.7512e-05
#     d_f = 3.7512e-05
#
#   At hop Switch_2 -> ES_4, output port 2, link_id Link_4:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_35']
#     For Stream_21: b_total_H = 0, l_max_L = 4384, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 6976, b_j = 4208, l_j_min = 4208, d_f_temp = 1.5568e-05
#         For j = Stream_22: b_C_j = 4208, b_j = 6976, l_j_min = 6976, d_f_temp = 1.5568e-05
#     d_f = 1.5568e-05
#
# Total delay for stream Stream_21: 6.978400000000001e-05
#
# Calculating delay for stream: Stream_22, size: 6976, period: 0.001, deadline: 0.007356, pcp: 7
#   At hop ES_6 -> Switch_3, output port 1, link_id Link_6:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_22: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_21: b_C_j = 6976, b_j = 4208, l_j_min = 4208, d_f_temp = 1.6704e-05
#         For j = Stream_22: b_C_j = 4208, b_j = 6976, l_j_min = 6976, d_f_temp = 1.6704e-05
#     d_f = 1.6704e-05
#
#   At hop Switch_3 -> Switch_2, output port 3, link_id Link_14:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_18', 'Stream_19', 'Stream_20', 'Stream_21', 'Stream_22']
#     Lower-priority streams: ['Stream_23', 'Stream_24']
#     For Stream_22: b_total_H = 0, l_max_L = 5520, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_18: b_C_j = 24192, b_j = 7800, l_j_min = 7800, d_f_temp = 3.7512e-05
# ...
#     Higher-priority streams: ['Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34', 'Stream_35']
#     For Stream_33: b_total_H = 5536, l_max_L = 5624, r = 1000000000, r_total_H = 5536000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 7032, l_j_min = 7032, d_f_temp = 1.82541256878077e-05
#     d_f = 1.82541256878077e-05
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     For Stream_33: b_total_H = 5536, l_max_L = 7944, r = 1000000000, r_total_H = 5536000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 7032, l_j_min = 7032, d_f_temp = 2.0587040705344787e-05
#     d_f = 2.0587040705344787e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_30', 'Stream_34', 'Stream_40']
#     For Stream_33: b_total_H = 45064, l_max_L = 7944, r = 1000000000, r_total_H = 55380000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 7032, l_j_min = 7032, d_f_temp = 6.314768673117232e-05
#     d_f = 6.314768673117232e-05
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_2', 'Stream_6', 'Stream_36']
#     Same-priority streams: ['Stream_33']
#     Lower-priority streams: ['Stream_34']
#     For Stream_33: b_total_H = 18784, l_max_L = 5624, r = 1000000000, r_total_H = 23428000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_33: b_C_j = 0, b_j = 7032, l_j_min = 7032, d_f_temp = 3.202554886275666e-05
#     d_f = 3.202554886275666e-05
#
# Total delay for stream Stream_33: 0.00013401440198708146
#
# Calculating delay for stream: Stream_34, size: 5624, period: 0.0005, deadline: 0.005841, pcp: 0
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 12568, l_max_L = 0, r = 1000000000, r_total_H = 12568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 4384, b_j = 5624, l_j_min = 5624, d_f_temp = 2.2791764463780797e-05
#         For j = Stream_35: b_C_j = 5624, b_j = 4384, l_j_min = 4384, d_f_temp = 2.280754714046132e-05
#     d_f = 2.280754714046132e-05
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 12568, l_max_L = 0, r = 1000000000, r_total_H = 12568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 12328, b_j = 5624, l_j_min = 5624, d_f_temp = 3.083687541825665e-05
#         For j = Stream_35: b_C_j = 13568, b_j = 4384, l_j_min = 4384, d_f_temp = 3.085265809493717e-05
#         For j = Stream_40: b_C_j = 10008, b_j = 7944, l_j_min = 7944, d_f_temp = 3.0807346539306e-05
#     d_f = 3.085265809493717e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 57168, l_max_L = 0, r = 1000000000, r_total_H = 67484000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 7944, b_j = 5624, l_j_min = 5624, d_f_temp = 7.544800301978733e-05
#         For j = Stream_40: b_C_j = 5624, b_j = 7944, l_j_min = 7944, d_f_temp = 7.528011005065865e-05
#     d_f = 7.544800301978733e-05
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_2', 'Stream_6', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34']
#     Lower-priority streams: []
#     For Stream_34: b_total_H = 25816, l_max_L = 0, r = 1000000000, r_total_H = 30460000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 0, b_j = 5624, l_j_min = 5624, d_f_temp = 3.225106025537884e-05
#     d_f = 3.225106025537884e-05
#
# Total delay for stream Stream_34: 0.00016135926851056466
#
# Calculating delay for stream: Stream_35, size: 4384, period: 0.002, deadline: 0.009433, pcp: 0
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 12568, l_max_L = 0, r = 1000000000, r_total_H = 12568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 4384, b_j = 5624, l_j_min = 5624, d_f_temp = 2.2791764463780797e-05
#         For j = Stream_35: b_C_j = 5624, b_j = 4384, l_j_min = 4384, d_f_temp = 2.280754714046132e-05
#     d_f = 2.280754714046132e-05
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 12568, l_max_L = 0, r = 1000000000, r_total_H = 12568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 12328, b_j = 5624, l_j_min = 5624, d_f_temp = 3.083687541825665e-05
#         For j = Stream_35: b_C_j = 13568, b_j = 4384, l_j_min = 4384, d_f_temp = 3.085265809493717e-05
#         For j = Stream_40: b_C_j = 10008, b_j = 7944, l_j_min = 7944, d_f_temp = 3.0807346539306e-05
#     d_f = 3.085265809493717e-05
#
#   At hop Switch_2 -> ES_4, output port 2, link_id Link_4:
#     Higher-priority streams: ['Stream_21', 'Stream_22']
#     Same-priority streams: ['Stream_35']
#     Lower-priority streams: []
#     For Stream_35: b_total_H = 11184, l_max_L = 0, r = 1000000000, r_total_H = 15392000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_35: b_C_j = 0, b_j = 4384, l_j_min = 4384, d_f_temp = 1.5742835191263936e-05
#     d_f = 1.5742835191263936e-05
#
# Total delay for stream Stream_35: 6.940304042666242e-05
#
# Calculating delay for stream: Stream_36, size: 5536, period: 0.001, deadline: 0.001219, pcp: 4
#   At hop ES_9 -> Switch_5, output port 1, link_id Link_9:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_33', 'Stream_34', 'Stream_35']
#     For Stream_36: b_total_H = 0, l_max_L = 7032, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 5536, l_j_min = 5536, d_f_temp = 1.2567999999999999e-05
#     d_f = 1.2567999999999999e-05
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_33', 'Stream_34', 'Stream_35', 'Stream_40']
#     For Stream_36: b_total_H = 0, l_max_L = 7944, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 5536, l_j_min = 5536, d_f_temp = 1.348e-05
#     d_f = 1.348e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_34', 'Stream_40']
#     For Stream_36: b_total_H = 7512, l_max_L = 7944, r = 1000000000, r_total_H = 15024000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 5536, l_j_min = 5536, d_f_temp = 2.122775289550202e-05
#     d_f = 2.122775289550202e-05
#
#   At hop Switch_3 -> ES_5, output port 1, link_id Link_5:
#     Higher-priority streams: ['Stream_6']
#     Same-priority streams: ['Stream_36']
#     Lower-priority streams: ['Stream_2', 'Stream_33', 'Stream_34']
#     For Stream_36: b_total_H = 7512, l_max_L = 7032, r = 1000000000, r_total_H = 15024000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_36: b_C_j = 0, b_j = 5536, l_j_min = 5536, d_f_temp = 2.0301842010363703e-05
#     d_f = 2.0301842010363703e-05
#
# Total delay for stream Stream_36: 6.757759490586572e-05
#
# Calculating delay for stream: Stream_37, size: 7960, period: 0.002, deadline: 0.010151, pcp: 5
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: ['Stream_38', 'Stream_40']
#     For Stream_37: b_total_H = 0, l_max_L = 7944, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 5784, b_j = 7960, l_j_min = 7960, d_f_temp = 2.1688e-05
#         For j = Stream_39: b_C_j = 7960, b_j = 5784, l_j_min = 5784, d_f_temp = 2.1688e-05
#     d_f = 2.1688e-05
#
#   At hop Switch_5 -> Switch_4, output port 4, link_id Link_15:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: []
#     For Stream_37: b_total_H = 0, l_max_L = 0, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 5784, b_j = 7960, l_j_min = 7960, d_f_temp = 1.3744e-05
#         For j = Stream_39: b_C_j = 7960, b_j = 5784, l_j_min = 5784, d_f_temp = 1.3744e-05
#     d_f = 1.3744e-05
#
#   At hop Switch_4 -> ES_7, output port 1, link_id Link_7:
#     Higher-priority streams: ['Stream_11', 'Stream_20']
#     Same-priority streams: ['Stream_37']
#     Lower-priority streams: ['Stream_15', 'Stream_31']
#     For Stream_37: b_total_H = 11856, l_max_L = 7048, r = 1000000000, r_total_H = 16664000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 0, b_j = 7960, l_j_min = 7960, d_f_temp = 2.718435464581791e-05
#     d_f = 2.718435464581791e-05
#
# Total delay for stream Stream_37: 6.26163546458179e-05
#
# Calculating delay for stream: Stream_38, size: 7560, period: 0.0005, deadline: 0.010905999999999999, pcp: 4
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: ['Stream_37', 'Stream_39']
#     Same-priority streams: ['Stream_38']
#     Lower-priority streams: ['Stream_40']
#     For Stream_38: b_total_H = 13744, l_max_L = 7944, r = 1000000000, r_total_H = 6872000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_38: b_C_j = 0, b_j = 7560, l_j_min = 7560, d_f_temp = 2.939807122546137e-05
#     d_f = 2.939807122546137e-05
#
#   At hop Switch_5 -> ES_9, output port 1, link_id Link_9:
#     Higher-priority streams: ['Stream_27']
#     Same-priority streams: ['Stream_14', 'Stream_38']
#     Lower-priority streams: ['Stream_10']
#     For Stream_38: b_total_H = 5752, l_max_L = 6536, r = 1000000000, r_total_H = 5752000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_14: b_C_j = 7560, b_j = 5504, l_j_min = 5504, d_f_temp = 2.5466826176165302e-05
#         For j = Stream_38: b_C_j = 5504, b_j = 7560, l_j_min = 7560, d_f_temp = 2.545493164683258e-05
#     d_f = 2.5466826176165302e-05
#
# Total delay for stream Stream_38: 5.486489740162667e-05
#
# Calculating delay for stream: Stream_39, size: 5784, period: 0.002, deadline: 0.016815999999999998, pcp: 5
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: ['Stream_38', 'Stream_40']
#     For Stream_39: b_total_H = 0, l_max_L = 7944, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 5784, b_j = 7960, l_j_min = 7960, d_f_temp = 2.1688e-05
#         For j = Stream_39: b_C_j = 7960, b_j = 5784, l_j_min = 5784, d_f_temp = 2.1688e-05
#     d_f = 2.1688e-05
#
#   At hop Switch_5 -> Switch_4, output port 4, link_id Link_15:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_37', 'Stream_39']
#     Lower-priority streams: []
#     For Stream_39: b_total_H = 0, l_max_L = 0, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_37: b_C_j = 5784, b_j = 7960, l_j_min = 7960, d_f_temp = 1.3744e-05
#         For j = Stream_39: b_C_j = 7960, b_j = 5784, l_j_min = 5784, d_f_temp = 1.3744e-05
#     d_f = 1.3744e-05
#
#   At hop Switch_4 -> Switch_1, output port 3, link_id Link_11:
#     Higher-priority streams: ['Stream_26']
#     Same-priority streams: ['Stream_39']
#     Lower-priority streams: ['Stream_29', 'Stream_30']
#     For Stream_39: b_total_H = 4384, l_max_L = 5952, r = 1000000000, r_total_H = 8768000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_39: b_C_j = 0, b_j = 5784, l_j_min = 5784, d_f_temp = 1.6211427685950414e-05
#     d_f = 1.6211427685950414e-05
#
#   At hop Switch_1 -> ES_2, output port 2, link_id Link_2:
#     Higher-priority streams: []
#     Same-priority streams: ['Stream_39']
#     Lower-priority streams: ['Stream_13', 'Stream_29']
#     For Stream_39: b_total_H = 0, l_max_L = 6096, r = 1000000000, r_total_H = 0
#
#     Iterating through same-priority streams:
#         For j = Stream_39: b_C_j = 0, b_j = 5784, l_j_min = 5784, d_f_temp = 1.188e-05
#     d_f = 1.188e-05
#
# Total delay for stream Stream_39: 6.352342768595041e-05
#
# Calculating delay for stream: Stream_40, size: 7944, period: 0.0005, deadline: 0.015182, pcp: 0
#   At hop ES_10 -> Switch_5, output port 1, link_id Link_10:
#     Higher-priority streams: ['Stream_37', 'Stream_39', 'Stream_38']
#     Same-priority streams: ['Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 21304, l_max_L = 0, r = 1000000000, r_total_H = 21992000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_40: b_C_j = 0, b_j = 7944, l_j_min = 7944, d_f_temp = 2.9727052899362786e-05
#     d_f = 2.9727052899362786e-05
#
#   At hop Switch_5 -> Switch_2, output port 3, link_id Link_13:
#     Higher-priority streams: ['Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_35', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 12568, l_max_L = 0, r = 1000000000, r_total_H = 12568000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 12328, b_j = 5624, l_j_min = 5624, d_f_temp = 3.083687541825665e-05
#         For j = Stream_35: b_C_j = 13568, b_j = 4384, l_j_min = 4384, d_f_temp = 3.085265809493717e-05
#         For j = Stream_40: b_C_j = 10008, b_j = 7944, l_j_min = 7944, d_f_temp = 3.0807346539306e-05
#     d_f = 3.085265809493717e-05
#
#   At hop Switch_2 -> Switch_3, output port 5, link_id Link_14:
#     Higher-priority streams: ['Stream_2', 'Stream_3', 'Stream_4', 'Stream_8', 'Stream_6', 'Stream_9', 'Stream_30', 'Stream_33', 'Stream_36']
#     Same-priority streams: ['Stream_34', 'Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 57168, l_max_L = 0, r = 1000000000, r_total_H = 67484000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_34: b_C_j = 7944, b_j = 5624, l_j_min = 5624, d_f_temp = 7.544800301978733e-05
#         For j = Stream_40: b_C_j = 5624, b_j = 7944, l_j_min = 7944, d_f_temp = 7.528011005065865e-05
#     d_f = 7.544800301978733e-05
#
#   At hop Switch_3 -> ES_6, output port 2, link_id Link_6:
#     Higher-priority streams: ['Stream_3', 'Stream_4', 'Stream_8', 'Stream_9', 'Stream_17', 'Stream_30']
#     Same-priority streams: ['Stream_40']
#     Lower-priority streams: []
#     For Stream_40: b_total_H = 38944, l_max_L = 0, r = 1000000000, r_total_H = 40820000.0
#
#     Iterating through same-priority streams:
#         For j = Stream_40: b_C_j = 0, b_j = 7944, l_j_min = 7944, d_f_temp = 4.854534698388206e-05
#     d_f = 4.854534698388206e-05
#
# Total delay for stream Stream_40: 0.0001845730609979693
